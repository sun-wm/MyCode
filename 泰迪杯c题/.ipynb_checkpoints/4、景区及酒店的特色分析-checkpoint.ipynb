# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
import jieba
import re
from collections import Counter
import csv

from tqdm import tqdm



from tqdm import tqdm_notebook
from scipy.linalg import norm

from gensim.models import Word2Vec
from gensim.models.keyedvectors import KeyedVectors
from gensim.models.word2vec import LineSentence




import jieba  
from sklearn import feature_extraction  
from sklearn.feature_extraction.text import TfidfTransformer  
from sklearn.feature_extraction.text import CountVectorizer  

import pyecharts.options as opts
from pyecharts.charts import WordCloud

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 一、景区特色分析

# %%
content = pd.read_excel(r"./附件1/景区评论.xlsx",engine='openpyxl')  
content.head()
# Out:
#   景区名称        评论日期                                               评论内容
# 0  A01  2020-06-16  是亲子游的绝佳场所，门票就是有点贵，不过可以接受，爷爷奶奶不放心小朋友也跟上来了，当天我们十...
# 1  A01  2020-01-23  **景区差不多，票价偏贵了。大马戏比较精彩，八点的场次，6点40才能检票进入，我们6点多看看...
# 2  A01  2020-03-22  很有**特色的亲子酒店，房间里的装修很可爱，小孩子特别喜欢，洗漱用品也很有特色，对应的房间还...
# 3  A01  2020-12-25  有园区的工作人员在那，他会主动给你园区里的地图和表演的时间安排，很周到，上接驳车大概也是34...
# 4  A01  2020-11-28  周五逃课跟朋友在广州集合！终于如愿以偿的到达欢乐世界。学生票198 需要出示相关证件（校卡或...

# %%
#使用停用词
def stopwordslist(filepath):
    stopwords = [line.strip() for line in open(filepath, 'r', encoding='utf-8').readlines()]
    return stopwords

# %%
scenic_name = list(content.groupby('景区名称'))
names = []
for name in scenic_name:
    name = name[0]
    names.append(name)
names
# Out:
# ['A01',
#  'A02',
#  'A03',
#  'A04',
#  'A05',
#  'A06',
#  'A07',
#  'A08',
#  'A09',
#  'A10',
#  'A11',
#  'A12',
#  'A13',
#  'A14',
#  'A15',
#  'A16',
#  'A17',
#  'A18',
#  'A19',
#  'A20',
#  'A21',
#  'A22',
#  'A23',
#  'A24',
#  'A25',
#  'A26',
#  'A27',
#  'A28',
#  'A29',
#  'A30',
#  'A31',
#  'A32',
#  'A33',
#  'A34',
#  'A35',
#  'A36',
#  'A37',
#  'A38',
#  'A39',
#  'A40',
#  'A41',
#  'A42',
#  'A43',
#  'A44',
#  'A45',
#  'A46',
#  'A47',
#  'A48',
#  'A49',
#  'A50']

# %%
A01 = content.loc[content['景区名称']=='A01']

# %%
def scenic_spot_participle(scenic_spot_name):
    stopwords = stopwordslist('hit_stopwords.txt')
    words = jieba.lcut(' '.join(scenic_spot_name['评论内容'].values))
    for i in tqdm(words):
            if i in stopwords:
                words.remove(i)
    words = ' '.join(words)
    return words

# %%
def words_name(words_name):
    vectorizer=CountVectorizer()         #该类会将文本中的词语转换为词频矩阵，矩阵元素a[i][j] 表示j词在i类文本下的词频  
    transformer=TfidfTransformer()       #该类会统计每个词语的tf-idf权值  
    X=vectorizer.fit_transform([words_name])   #将文本转为词频矩阵
    tfidf=transformer.fit_transform(X)   #计算tf-idf，  
    word=vectorizer.get_feature_names()  #获取词袋模型中的所有词语   
    weight=tfidf.toarray()               #将tf-idf矩阵抽取出来，元素a[i][j]表示j词在i类文本中的tf-idf权重  

    spec = []

    for  w in  weight:
            loc = np.argsort(-w)
            for i in range(50):
                print(u'-{}: {} {}'.format(str(i + 1), word[loc[i]], w[loc[i]]))
                spec.append((word[loc[i]], str(w[loc[i]])))
    return spec

# %%
words_A01 = scenic_spot_participle(A01)
# Out:
#  71%|███████████████████████████████████████████████████▍                    | 134367/187931 [00:59<00:23, 2265.66it/s]

# %%
words_A01_spec = words_name(words_A01)
# Out:
# -1: 方便 0.3270192600460427
# -2: 取票 0.26623161282574404
# -3: 动物 0.2545768383586943
# -4: 非常 0.23012466447684485
# -5: 不错 0.21641316510384515
# -6: 表演 0.18396261658774588
# -7: 很多 0.17962064178629597
# -8: 好玩 0.16636619239239628
# -9: 马戏 0.15516846790444652
# -10: 里面 0.14602746832244673
# -11: 开心 0.14122844354189684
# -12: 值得 0.12774546915844714
# -13: 动物园 0.12728841917934716
# -14: 景区 0.12568874425249718
# -15: 项目 0.11791889460779736
# -16: 排队 0.11700479464959739
# -17: 孩子 0.11654774467049739
# -18: 过山车 0.11517659473319743
# -19: 真的 0.11266281984814748
# -20: 刺激 0.11152019490039751
# -21: 可以 0.10352182026614769
# -22: 没有 0.10100804538109774
# -23: 时间 0.09872279548559779
# -24: 精彩 0.09803722051694781
# -25: 比较 0.09780869552739781
# -26: 便宜 0.09552344563189787
# -27: 世界 0.09529492064234786
# -28: 就是 0.09506639565279787
# -29: 火车 0.09438082068414788
# -30: 特别 0.08569687108124809
# -31: 一天 0.08318309619619814
# -32: 喜欢 0.08204047124844817
# -33: 小朋友 0.07129979673959841
# -34: 园区 0.06992864680229843
# -35: 进去 0.06901454684409845
# -36: 垂直 0.06901454684409845
# -37: 感觉 0.06650077195904851
# -38: 我们 0.06558667200084853
# -39: 下次 0.06490109703219855
# -40: 欢乐 0.06398699707399856
# -41: 地方 0.0626158471366986
# -42: 超级 0.06147322218894862
# -43: 网上 0.06078764722029864
# -44: 有点 0.06010207225164865
# -45: 游玩 0.059187972293448673
# -46: 一定 0.058273872335248694
# -47: 建议 0.056674197408398734
# -48: 酒店 0.056217147429298744
# -49: 门票 0.055988622439748746
# -50: 乐园 0.055531572460648757

# %%
data = words_A01_spec


(
    WordCloud()
    .add(series_name="A01景区特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="A01景区特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="4e776d74034041039f91e15018d9f281" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_4e776d74034041039f91e15018d9f281 = echarts.init(
#                     document.getElementById('4e776d74034041039f91e15018d9f281'), 'white', {renderer: 'canvas'});
#                 var option_4e776d74034041039f91e15018d9f281 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "A01\u666f\u533a\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u65b9\u4fbf",
#                     "value": "0.3270192600460427",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(8,98,35)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53d6\u7968",
#                     "value": "0.26623161282574404",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(32,6,77)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u52a8\u7269",
#                     "value": "0.2545768383586943",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(121,111,47)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": "0.23012466447684485",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(65,18,53)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.21641316510384515",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(121,34,12)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8868\u6f14",
#                     "value": "0.18396261658774588",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(106,145,105)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f88\u591a",
#                     "value": "0.17962064178629597",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(63,39,0)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u597d\u73a9",
#                     "value": "0.16636619239239628",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(3,143,12)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9a6c\u620f",
#                     "value": "0.15516846790444652",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(4,101,102)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u91cc\u9762",
#                     "value": "0.14602746832244673",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(118,78,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f00\u5fc3",
#                     "value": "0.14122844354189684",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(0,94,140)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u503c\u5f97",
#                     "value": "0.12774546915844714",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(154,23,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u52a8\u7269\u56ed",
#                     "value": "0.12728841917934716",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(89,152,44)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u666f\u533a",
#                     "value": "0.12568874425249718",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(100,32,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9879\u76ee",
#                     "value": "0.11791889460779736",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(120,9,133)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6392\u961f",
#                     "value": "0.11700479464959739",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(72,157,32)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b69\u5b50",
#                     "value": "0.11654774467049739",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(77,58,72)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fc7\u5c71\u8f66",
#                     "value": "0.11517659473319743",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(39,139,64)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u771f\u7684",
#                     "value": "0.11266281984814748",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(95,134,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u523a\u6fc0",
#                     "value": "0.11152019490039751",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,125,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53ef\u4ee5",
#                     "value": "0.10

# %% [markdown]
# # 二、酒店特色分析

# %%
content_hotel = pd.read_excel(r"./附件1/酒店评论.xlsx",engine='openpyxl')  
content_hotel.head()
# Out:
#   酒店名称        评论日期                                               评论内容  入住房型
# 0  H01  2020-01-01                                          酒店很适合家庭出行  标准客房
# 1  H01  2020-01-01                                      升级了房间 延迟退房 很赞  标准客房
# 2  H01  2020-01-01  这几年，每年都会来广州，每次都会住**酒店。因为位置好，酒店的性价比也不错，这次给免费升级了...  标准客房
# 3  H01  2020-01-01                                             酒店很好不错  标准客房
# 4  H01  2020-01-01                                              超五星好评  高级客房

# %%
#使用停用词
def stopwordslist(filepath):
    stopwords = [line.strip() for line in open(filepath, 'r', encoding='utf-8').readlines()]
    return stopwords

# %%
hotel_name = list(content_hotel.groupby('酒店名称'))
hotel_names = []
for name in hotel_name:
    name = name[0]
    hotel_names.append(name)
hotel_names
# Out:
# ['H01',
#  'H02',
#  'H03',
#  'H04',
#  'H05',
#  'H06',
#  'H07',
#  'H08',
#  'H09',
#  'H10',
#  'H11',
#  'H12',
#  'H13',
#  'H14',
#  'H15',
#  'H16',
#  'H17',
#  'H18',
#  'H19',
#  'H20',
#  'H21',
#  'H22',
#  'H23',
#  'H24',
#  'H25',
#  'H26',
#  'H27',
#  'H28',
#  'H29',
#  'H30',
#  'H31',
#  'H32',
#  'H33',
#  'H34',
#  'H35',
#  'H36',
#  'H37',
#  'H38',
#  'H39',
#  'H40',
#  'H41',
#  'H42',
#  'H43',
#  'H44',
#  'H45',
#  'H46',
#  'H47',
#  'H48',
#  'H49',
#  'H50']

# %%
H01 = content_hotel.loc[content_hotel['酒店名称']=='H01']

# %%
words_H01 = scenic_spot_participle(H01)
# Out:
#  77%|████████████████████████████████████████████████████████                 | 10472/13626 [00:00<00:00, 24671.93it/s]

# %%
words_H01_spec = words_name(words_H01)
# Out:
# -1: 不错 0.5251258748550716
# -2: 酒店 0.4752326800944947
# -3: 服务 0.36796231135925445
# -4: 方便 0.31183246725360547
# -5: 位置 0.19084146995920653
# -6: 非常 0.18335749074512
# -7: 房间 0.15841089336483158
# -8: 交通 0.14593759467468737
# -9: 前台 0.12348565703242775
# -10: 环境 0.1147543479493268
# -11: 干净 0.10103371939016817
# -12: 早餐 0.09354974017608164
# -13: 便利 0.0910550804380528
# -14: 性价比 0.08232377135495184
# -15: 东站 0.079829111616923
# -16: 卫生 0.07483979214086531
# -17: 入住 0.06985047266480762
# -18: 服务态度 0.0686031427957932
# -19: 地理位置 0.06361382331973552
# -20: 设施 0.0573771739746634
# -21: 比较 0.04864586489156245
# -22: 出差 0.04864586489156245
# -23: 广州东站 0.04615120515353361
# -24: 附近 0.04490387528451918
# -25: 出行 0.04365654541550476
# -26: 下次 0.04365654541550476
# -27: 选择 0.04240921554649034
# -28: 地铁 0.0399145558084615
# -29: 满意 0.037419896070432654
# -30: 舒适 0.037419896070432654
# -31: 广州 0.037419896070432654
# -32: 推荐 0.03492523633240381
# -33: 舒服 0.03492523633240381
# -34: 周边 0.03367790646338939
# -35: 五星 0.03243057659437497
# -36: 五星级 0.03243057659437497
# -37: 有点 0.03243057659437497
# -38: 特别 0.031183246725360544
# -39: 热情 0.029935916856346122
# -40: 靠近 0.029935916856346122
# -41: 价格 0.0286885869873317
# -42: 丰富 0.02744125711831728
# -43: 对面 0.02744125711831728
# -44: 喜欢 0.02744125711831728
# -45: 值得 0.024946597380288437
# -46: 感觉 0.024946597380288437
# -47: 老牌 0.02245193764225959
# -48: 很多 0.02245193764225959
# -49: 没有 0.02245193764225959
# -50: 还会 0.02120460777324517

# %%
import pyecharts.options as opts
from pyecharts.charts import WordCloud

data = words_H01_spec


(
    WordCloud()
    .add(series_name="H01酒店特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="H01酒店特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="bc5f8a659ccd4bfe8bc963388278f855" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_bc5f8a659ccd4bfe8bc963388278f855 = echarts.init(
#                     document.getElementById('bc5f8a659ccd4bfe8bc963388278f855'), 'white', {renderer: 'canvas'});
#                 var option_bc5f8a659ccd4bfe8bc963388278f855 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "H01\u9152\u5e97\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.5251258748550716",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(106,104,157)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9152\u5e97",
#                     "value": "0.4752326800944947",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(44,106,67)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u670d\u52a1",
#                     "value": "0.36796231135925445",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(40,91,151)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b9\u4fbf",
#                     "value": "0.31183246725360547",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,129,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f4d\u7f6e",
#                     "value": "0.19084146995920653",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(158,123,13)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": "0.18335749074512",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(6,155,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u623f\u95f4",
#                     "value": "0.15841089336483158",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(59,135,148)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4ea4\u901a",
#                     "value": "0.14593759467468737",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,157,116)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u524d\u53f0",
#                     "value": "0.12348565703242775",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(112,70,15)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73af\u5883",
#                     "value": "0.1147543479493268",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(153,145,137)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e72\u51c0",
#                     "value": "0.10103371939016817",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(136,109,28)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65e9\u9910",
#                     "value": "0.09354974017608164",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(119,107,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4fbf\u5229",
#                     "value": "0.0910550804380528",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(80,126,3)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6027\u4ef7\u6bd4",
#                     "value": "0.08232377135495184",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(16,30,48)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e1c\u7ad9",
#                     "value": "0.079829111616923",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(43,15,58)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u536b\u751f",
#                     "value": "0.07483979214086531",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(139,125,51)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5165\u4f4f",
#                     "value": "0.06985047266480762",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(3,40,58)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u670d\u52a1\u6001\u5ea6",
#                     "value": "0.0686031427957932",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,16,4)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5730\u7406\u4f4d\u7f6e",
#                     "value": "0.06361382331973552",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(2,76,4)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bbe\u65bd",
#                     "value": "0.0573771739746634",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,48,102)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6bd4\u8f83",
#                     "

# %% [markdown]
# # 三、请选择综合评价高、中、低三个层次的各 3 家景点和 3家酒店，结合模型的结果，分析他们各自的特色。

# %% [markdown]
# ## (1、)综合评价景区的高中低特色

# %%
content = pd.read_excel(r"./附件2/景区评分.xlsx",engine='openpyxl')  
content.head()
# Out:
#   景区名称    总得分  服务得分  位置得分  设施得分  卫生得分  性价比得分
# 0  A01  4.390   3.8   4.9   4.9   4.5    4.5
# 1  A02  4.210   3.8   4.9   4.2   4.5    4.0
# 2  A03  4.230   3.9   4.2   4.1   4.5    4.5
# 3  A04  4.165   3.8   4.0   4.0   4.5    4.5
# 4  A05  4.240   3.9   4.9   4.0   4.5    4.2

# %% [markdown]
# ## 按总得分划分出高中低3个层次

# %% [markdown]
# ### 综合评价高的景区

# %%
content = pd.read_excel(r"./附件2/景区评分.xlsx",engine='openpyxl')

# %%
#找出综合评分高于3.6的景点
content_high = content.loc[content['总得分']>4.6].sort_values('总得分',ascending=False)
content_high.head()
# Out:
#    景区名称    总得分  服务得分  位置得分  设施得分  卫生得分  性价比得分
# 38  A39  4.885   4.9   4.9   4.9   4.9    4.8
# 37  A38  4.840   4.9   4.9   4.5   4.9    4.9
# 22  A23  4.765   4.9   4.9   4.9   4.9    4.0
# 36  A37  4.675   4.9   4.9   4.9   4.2    4.8
# 39  A40  4.630   4.0   4.9   4.9   4.9    4.9

# %%
content_high_scenic = pd.read_excel(r"./附件1/景区评论.xlsx",engine='openpyxl')

# %%
A39 = content_high_scenic.loc[content_high_scenic['景区名称'] == 'A39']

# %%
words_A39 = scenic_spot_participle(A39)
# Out:
#  71%|█████████████████████████████████████████████████████▏                     | 4621/6523 [00:00<00:00, 37056.63it/s]

# %%
words_A39_spec = words_name(words_A39)
# Out:
# -1: 不错 0.3818806540799698
# -2: 动物 0.3769847482584317
# -3: 公园 0.3231297842215129
# -4: 里面 0.22031576196921335
# -5: 值得 0.20073213868306106
# -6: 很多 0.20073213868306106
# -7: 地方 0.19583623286152296
# -8: 好玩 0.16156489211075645
# -9: 适合 0.15666898628921838
# -10: 门票 0.14687717464614222
# -11: 比较 0.14198126882460416
# -12: 环境 0.1370853630030661
# -13: 非常 0.12729355135998993
# -14: 小孩 0.12729355135998993
# -15: 喜欢 0.1126058338953757
# -16: 开心 0.10770992807383764
# -17: 空气 0.09791811643076148
# -18: 小孩子 0.09302221060922342
# -19: 景点 0.09302221060922342
# -20: 可以 0.08323039896614727
# -21: 表演 0.07833449314460919
# -22: 茂名 0.07833449314460919
# -23: 游玩 0.07833449314460919
# -24: 感觉 0.07833449314460919
# -25: 景色 0.07833449314460919
# -26: 动物园 0.07833449314460919
# -27: 孩子 0.07833449314460919
# -28: 景区 0.07343858732307111
# -29: 小朋友 0.07343858732307111
# -30: 很大 0.06854268150153305
# -31: 有点 0.06854268150153305
# -32: 植物 0.06364677567999497
# -33: 项目 0.05875086985845689
# -34: 没有 0.05875086985845689
# -35: 风景 0.05875086985845689
# -36: 下次 0.05385496403691882
# -37: 好好 0.05385496403691882
# -38: 空气清新 0.05385496403691882
# -39: 水上 0.05385496403691882
# -40: 一去 0.05385496403691882
# -41: 方便 0.05385496403691882
# -42: 设施 0.05385496403691882
# -43: 还有 0.05385496403691882
# -44: 一家 0.04895905821538074
# -45: 总体 0.04895905821538074
# -46: 真的 0.04895905821538074
# -47: 优惠 0.04895905821538074
# -48: 性价比 0.04895905821538074
# -49: 一个 0.04895905821538074
# -50: 特别 0.04895905821538074

# %%
import pyecharts.options as opts
from pyecharts.charts import WordCloud

data = words_A39_spec


(
    WordCloud()
    .add(series_name="A39景点特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="A39景点特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="ecbb1cb22b9d4ca1a1e70cce83dd27f2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_ecbb1cb22b9d4ca1a1e70cce83dd27f2 = echarts.init(
#                     document.getElementById('ecbb1cb22b9d4ca1a1e70cce83dd27f2'), 'white', {renderer: 'canvas'});
#                 var option_ecbb1cb22b9d4ca1a1e70cce83dd27f2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "A39\u666f\u70b9\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.3818806540799698",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(28,66,137)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u52a8\u7269",
#                     "value": "0.3769847482584317",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(148,121,50)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u56ed",
#                     "value": "0.3231297842215129",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(6,105,0)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u91cc\u9762",
#                     "value": "0.22031576196921335",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(107,147,49)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u503c\u5f97",
#                     "value": "0.20073213868306106",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(14,61,117)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f88\u591a",
#                     "value": "0.20073213868306106",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(26,62,135)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5730\u65b9",
#                     "value": "0.19583623286152296",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(160,57,158)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u597d\u73a9",
#                     "value": "0.16156489211075645",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(90,95,15)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9002\u5408",
#                     "value": "0.15666898628921838",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(2,108,93)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u95e8\u7968",
#                     "value": "0.14687717464614222",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(15,121,102)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6bd4\u8f83",
#                     "value": "0.14198126882460416",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(68,23,109)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73af\u5883",
#                     "value": "0.1370853630030661",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,137,91)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": "0.12729355135998993",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(116,11,134)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c0f\u5b69",
#                     "value": "0.12729355135998993",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(10,11,52)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u559c\u6b22",
#                     "value": "0.1126058338953757",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(64,81,58)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f00\u5fc3",
#                     "value": "0.10770992807383764",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(78,142,47)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7a7a\u6c14",
#                     "value": "0.09791811643076148",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(159,8,82)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c0f\u5b69\u5b50",
#                     "value": "0.09302221060922342",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,33,139)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u666f\u70b9",
#                     "value": "0.09302221060922342",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(23,120,30)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53ef\u4ee5",
#                     "value": "0.08323039896614727",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,99,65)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8868\u6f14",
#                     "value": "0.07833449314

# %%
A38 = content_high_scenic.loc[content_high_scenic['景区名称'] == 'A38']

# %%
words_A38 = scenic_spot_participle(A38)
# Out:
#  71%|█████████████████████████████████████████████████████▍                     | 6546/9183 [00:00<00:00, 31557.32it/s]

# %%
words_A38_spec = words_name(words_A38)
# Out:
# -1: 温泉 0.6420985987647039
# -2: 不错 0.28578954973920345
# -3: 环境 0.200423840076844
# -4: 很多 0.18186607710676583
# -5: 非常 0.15959676154267208
# -6: 服务 0.12248123560251577
# -7: 干净 0.12248123560251577
# -8: 比较 0.11876968300850015
# -9: 感觉 0.11876968300850015
# -10: 还有 0.11134657782046889
# -11: 地方 0.10763502522645325
# -12: 舒服 0.10763502522645325
# -13: 阳西 0.10763502522645325
# -14: 下次 0.10763502522645325
# -15: 里面 0.10392347263243762
# -16: 没有 0.100211920038422
# -17: 开心 0.100211920038422
# -18: 设施 0.0890772622563751
# -19: 值得 0.0890772622563751
# -20: 方便 0.0890772622563751
# -21: 真的 0.0890772622563751
# -22: 水上 0.07794260447432821
# -23: 乐园 0.07423105188031259
# -24: 泡温泉 0.07051949928629696
# -25: 就是 0.07051949928629696
# -26: 有点 0.07051949928629696
# -27: 咸水 0.06680794669228134
# -28: 不是 0.06680794669228134
# -29: 游泳池 0.06680794669228134
# -30: 玩得 0.0630963940982657
# -31: 好玩 0.0630963940982657
# -32: 喜欢 0.05938484150425007
# -33: 朋友 0.05938484150425007
# -34: 免费 0.05938484150425007
# -35: 毛巾 0.055673288910234445
# -36: 希望 0.055673288910234445
# -37: 满意 0.055673288910234445
# -38: 觉得 0.05196173631621881
# -39: 一个 0.05196173631621881
# -40: 一下 0.04825018372220318
# -41: 可以 0.04825018372220318
# -42: 水质 0.04825018372220318
# -43: 服务态度 0.04825018372220318
# -44: 而且 0.04453863112818755
# -45: 这次 0.04453863112818755
# -46: 价格 0.04453863112818755
# -47: 还会 0.04453863112818755
# -48: 泳池 0.040827078534171925
# -49: 大家 0.040827078534171925
# -50: 晚上 0.040827078534171925

# %%
import pyecharts.options as opts
from pyecharts.charts import WordCloud

data = words_A38_spec


(
    WordCloud()
    .add(series_name="A38景点特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="A38景点特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="ec3075ee1db74ba38e63de6a4a5cd1af" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_ec3075ee1db74ba38e63de6a4a5cd1af = echarts.init(
#                     document.getElementById('ec3075ee1db74ba38e63de6a4a5cd1af'), 'white', {renderer: 'canvas'});
#                 var option_ec3075ee1db74ba38e63de6a4a5cd1af = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "A38\u666f\u70b9\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u6e29\u6cc9",
#                     "value": "0.6420985987647039",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,29,135)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.28578954973920345",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,87,22)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73af\u5883",
#                     "value": "0.200423840076844",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(159,98,96)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f88\u591a",
#                     "value": "0.18186607710676583",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,128,125)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": "0.15959676154267208",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(73,145,113)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u670d\u52a1",
#                     "value": "0.12248123560251577",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(160,146,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e72\u51c0",
#                     "value": "0.12248123560251577",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(65,107,83)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6bd4\u8f83",
#                     "value": "0.11876968300850015",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(106,92,0)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u611f\u89c9",
#                     "value": "0.11876968300850015",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(87,41,145)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fd8\u6709",
#                     "value": "0.11134657782046889",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(68,75,44)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5730\u65b9",
#                     "value": "0.10763502522645325",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(142,7,120)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8212\u670d",
#                     "value": "0.10763502522645325",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(6,94,32)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9633\u897f",
#                     "value": "0.10763502522645325",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(128,64,4)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0b\u6b21",
#                     "value": "0.10763502522645325",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(138,146,136)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u91cc\u9762",
#                     "value": "0.10392347263243762",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(114,73,2)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ca1\u6709",
#                     "value": "0.100211920038422",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(150,152,114)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f00\u5fc3",
#                     "value": "0.100211920038422",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(35,36,83)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bbe\u65bd",
#                     "value": "0.0890772622563751",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(27,146,113)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u503c\u5f97",
#                     "value": "0.0890772622563751",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,144,53)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b9\u4fbf",
#                     "value": "0.0890772622563751",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,149,95)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u771f\u7684",
#                     "value": "0.0890772622563751

# %%
A23 = content_high_scenic.loc[content_high_scenic['景区名称'] == 'A23']

# %%
words_A23 = scenic_spot_participle(A23)
# Out:
#  71%|███████████████████████████████████████████████████▊                     | 11792/16616 [00:00<00:00, 21693.13it/s]

# %%
words_A23_spec = words_name(words_A23)
# Out:
# -1: 不错 0.4379551585040997
# -2: 园林 0.3290221495360749
# -3: 值得 0.2934521874240668
# -4: 中山 0.22231226320005062
# -5: 地方 0.19563479161604455
# -6: 景色 0.18896542372004302
# -7: 环境 0.16673419740003798
# -8: 方便 0.15561858424003544
# -9: 岭南 0.1467260937120334
# -10: 里面 0.1422798484480324
# -11: 门票 0.13561048055203087
# -12: 感觉 0.12671799002402886
# -13: 有点 0.11560237686402633
# -14: 苏州园林 0.11560237686402633
# -15: 比较 0.11337925423202581
# -16: 非常 0.11337925423202581
# -17: 适合 0.11115613160002531
# -18: 风景 0.1044867637040238
# -19: 特色 0.10004051844002278
# -20: 取票 0.09781739580802228
# -21: 景点 0.09559427317602177
# -22: 一去 0.08670178264801974
# -23: 建筑 0.08670178264801974
# -24: 没有 0.08447866001601924
# -25: 可以 0.0755861694880172
# -26: 便宜 0.0733630468560167
# -27: 很多 0.0733630468560167
# -28: 古典 0.0711399242240162
# -29: 园子 0.0711399242240162
# -30: 精致 0.0711399242240162
# -31: 风格 0.0711399242240162
# -32: 小时 0.06891680159201569
# -33: 很大 0.06891680159201569
# -34: 游玩 0.06669367896001518
# -35: 好玩 0.06447055632801468
# -36: 喜欢 0.062247433696014175
# -37: 看看 0.060024311064013666
# -38: 就是 0.055578065800012656
# -39: 景区 0.055578065800012656
# -40: 江南 0.055578065800012656
# -41: 休闲 0.055578065800012656
# -42: 古色古香 0.05335494316801215
# -43: 不是 0.051131820536011646
# -44: 很漂亮 0.051131820536011646
# -45: 漂亮 0.04890869790401114
# -46: 不过 0.04668557527201063
# -47: 好去处 0.04668557527201063
# -48: 一个 0.04668557527201063
# -49: 母亲 0.04446245264001012
# -50: 网上 0.04446245264001012

# %%
import pyecharts.options as opts
from pyecharts.charts import WordCloud

data = words_A23_spec


(
    WordCloud()
    .add(series_name="A23景点特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="A23景点特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="3a322d74b66c4d0fa076855a7b9c8e5b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_3a322d74b66c4d0fa076855a7b9c8e5b = echarts.init(
#                     document.getElementById('3a322d74b66c4d0fa076855a7b9c8e5b'), 'white', {renderer: 'canvas'});
#                 var option_3a322d74b66c4d0fa076855a7b9c8e5b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "A23\u666f\u70b9\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.4379551585040997",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(43,115,127)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u56ed\u6797",
#                     "value": "0.3290221495360749",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(147,139,57)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u503c\u5f97",
#                     "value": "0.2934521874240668",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,89,54)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u5c71",
#                     "value": "0.22231226320005062",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(107,6,148)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5730\u65b9",
#                     "value": "0.19563479161604455",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(109,46,64)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u666f\u8272",
#                     "value": "0.18896542372004302",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(63,137,15)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73af\u5883",
#                     "value": "0.16673419740003798",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(156,21,137)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b9\u4fbf",
#                     "value": "0.15561858424003544",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(87,65,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5cad\u5357",
#                     "value": "0.1467260937120334",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(3,133,82)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u91cc\u9762",
#                     "value": "0.1422798484480324",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(132,46,143)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u95e8\u7968",
#                     "value": "0.13561048055203087",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(110,116,4)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u611f\u89c9",
#                     "value": "0.12671799002402886",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(124,34,103)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6709\u70b9",
#                     "value": "0.11560237686402633",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(90,84,56)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u82cf\u5dde\u56ed\u6797",
#                     "value": "0.11560237686402633",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(109,155,106)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6bd4\u8f83",
#                     "value": "0.11337925423202581",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(15,75,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": "0.11337925423202581",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(69,74,82)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9002\u5408",
#                     "value": "0.11115613160002531",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(140,70,15)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u98ce\u666f",
#                     "value": "0.1044867637040238",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(61,48,51)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7279\u8272",
#                     "value": "0.10004051844002278",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(135,120,62)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53d6\u7968",
#                     "value": "0.09781739580802228",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(8,110,148)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u666f\u70b9",
#                     "value": "0.095

# %% [markdown]
# ### 综合评价中的3个景区

# %%
content_med = content.loc[(4.3<=content['总得分']) & (content['总得分']<=4.6)].sort_values('总得分',ascending=False)
content_med.head()
# Out:
#    景区名称    总得分  服务得分  位置得分  设施得分  卫生得分  性价比得分
# 49  A50  4.585   3.9   4.9   4.9   4.9    4.8
# 35  A36  4.585   3.9   4.9   4.9   4.9    4.8
# 47  A48  4.570   4.2   4.9   4.2   4.9    4.8
# 34  A35  4.570   4.0   4.9   4.9   4.9    4.5
# 44  A45  4.555   3.9   4.9   4.9   4.9    4.6

# %%
content_med_scenic = pd.read_excel(r"./附件1/景区评论.xlsx",engine='openpyxl')

# %%
A50 = content_med_scenic.loc[content_med_scenic['景区名称'] == 'A50']

# %%
words_A50 = scenic_spot_participle(A50)
# Out:
#  71%|█████████████████████████████████████████████████████▍                     | 6648/9321 [00:00<00:00, 30025.97it/s]

# %%
words_A50_spec = words_name(words_A50)
# Out:
# -1: 景区 0.3344210243482231
# -2: 瀑布群 0.2554605047104482
# -3: 黄山 0.24152629536260556
# -4: 不错 0.20901314021763942
# -5: 公园 0.1718552486233924
# -6: 值得 0.1718552486233924
# -7: 非常 0.16256577572483066
# -8: 空气 0.16256577572483066
# -9: 景点 0.15327630282626892
# -10: 水谷 0.14863156637698804
# -11: 方便 0.14398682992770717
# -12: 景色 0.14398682992770717
# -13: 地方 0.14398682992770717
# -14: 瀑布 0.13005262057986453
# -15: 广东 0.13005262057986453
# -16: 门票 0.13005262057986453
# -17: 适合 0.13005262057986453
# -18: 风景 0.12540788413058365
# -19: 我们 0.12540788413058365
# -20: 酒店 0.11147367478274103
# -21: 开车 0.10682893833346016
# -22: 入口 0.10218420188417927
# -23: 空气清新 0.0975394654348984
# -24: 没有 0.09289472898561753
# -25: 出口 0.08824999253633665
# -26: 到达 0.08824999253633665
# -27: 可以 0.08360525608705577
# -28: 比较 0.08360525608705577
# -29: 时间 0.0789605196377749
# -30: 上山 0.0789605196377749
# -31: 一去 0.07431578318849402
# -32: 建议 0.06967104673921315
# -33: 感觉 0.06967104673921315
# -34: 小时 0.06502631028993226
# -35: 氧吧 0.06502631028993226
# -36: 负离子 0.06502631028993226
# -37: 环境 0.06502631028993226
# -38: 森林公园 0.06502631028993226
# -39: 很大 0.06502631028993226
# -40: 第一峰 0.06502631028993226
# -41: 因为 0.06502631028993226
# -42: 山顶 0.06038157384065139
# -43: 天然 0.06038157384065139
# -44: 有点 0.06038157384065139
# -45: 温泉 0.06038157384065139
# -46: 免费 0.06038157384065139
# -47: 自驾游 0.06038157384065139
# -48: 一天 0.06038157384065139
# -49: 很多 0.05573683739137052
# -50: 第二天 0.05573683739137052

# %%
import pyecharts.options as opts
from pyecharts.charts import WordCloud

data = words_A50_spec


(
    WordCloud()
    .add(series_name="A50景点特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="A50景点特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="21d918c2b82d49a6a85e071d6f71c46a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_21d918c2b82d49a6a85e071d6f71c46a = echarts.init(
#                     document.getElementById('21d918c2b82d49a6a85e071d6f71c46a'), 'white', {renderer: 'canvas'});
#                 var option_21d918c2b82d49a6a85e071d6f71c46a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "A50\u666f\u70b9\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u666f\u533a",
#                     "value": "0.3344210243482231",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(113,121,49)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7011\u5e03\u7fa4",
#                     "value": "0.2554605047104482",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(95,159,83)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9ec4\u5c71",
#                     "value": "0.24152629536260556",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(2,160,30)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.20901314021763942",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(34,53,2)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u56ed",
#                     "value": "0.1718552486233924",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,113,129)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u503c\u5f97",
#                     "value": "0.1718552486233924",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(147,61,37)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": "0.16256577572483066",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(99,60,131)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7a7a\u6c14",
#                     "value": "0.16256577572483066",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(149,63,60)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u666f\u70b9",
#                     "value": "0.15327630282626892",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,113,63)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6c34\u8c37",
#                     "value": "0.14863156637698804",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(82,32,81)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b9\u4fbf",
#                     "value": "0.14398682992770717",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(51,129,69)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u666f\u8272",
#                     "value": "0.14398682992770717",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(34,61,74)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5730\u65b9",
#                     "value": "0.14398682992770717",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(141,9,77)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7011\u5e03",
#                     "value": "0.13005262057986453",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(105,153,157)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": "0.13005262057986453",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(116,155,31)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u95e8\u7968",
#                     "value": "0.13005262057986453",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(112,14,21)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9002\u5408",
#                     "value": "0.13005262057986453",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(78,17,8)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u98ce\u666f",
#                     "value": "0.12540788413058365",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(127,90,27)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6211\u4eec",
#                     "value": "0.12540788413058365",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(129,60,100)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9152\u5e97",
#                     "value": "0.11147367478274103",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,127,115)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f00\u8f66",
#                     "value": "0.106828938

# %%
A36 = content_med_scenic.loc[content_med_scenic['景区名称'] == 'A36']
words_A36= scenic_spot_participle(A36)
words_A36_spec = words_name(words_A36)
data = words_A36_spec
# Out:
#  70%|███████████████████████████████████████████████████▌                      | 7824/11235 [00:00<00:00, 28118.14it/s]
# -1: 景区 0.46289331481780943
# -2: 陶瓷 0.3480146819433166
# -3: 不错 0.22637848242914765
# -4: 地方 0.21624213246963359
# -5: 佛山 0.18583308259109138
# -6: 景点 0.18245429927125334
# -7: 值得 0.18245429927125334
# -8: 里面 0.17569673263157728
# -9: 可以 0.15542403271254915
# -10: 门票 0.15542403271254915
# -11: 文化 0.13853011611335903
# -12: 特色 0.13177254947368297
# -13: 石湾 0.13177254947368297
# -14: 历史 0.11149984955465482
# -15: 方便 0.10474228291497877
# -16: 看看 0.10474228291497877
# -17: 喜欢 0.0946059329554647
# -18: 很多 0.09122714963562667
# -19: 便宜 0.08446958299595062
# -20: 一个 0.0810907996761126
# -21: 比较 0.07771201635627457
# -22: 公仔 0.07771201635627457
# -23: 了解 0.07771201635627457
# -24: 博物馆 0.07433323303643655
# -25: 陶艺 0.06757566639676049
# -26: 有点 0.06419688307692248
# -27: 非常 0.06419688307692248
# -28: 适合 0.06419688307692248
# -29: 进去 0.060818099757084444
# -30: 没有 0.057439316437246424
# -31: 生产 0.057439316437246424
# -32: 旅游 0.057439316437246424
# -33: 龙窑 0.057439316437246424
# -34: 一下 0.057439316437246424
# -35: 看到 0.054060533117408396
# -36: 还有 0.054060533117408396
# -37: 一去 0.054060533117408396
# -38: 建筑 0.054060533117408396
# -39: 环境 0.054060533117408396
# -40: 拍照 0.050681749797570376
# -41: 制陶 0.050681749797570376
# -42: 时间 0.050681749797570376
# -43: 文艺 0.04730296647773235
# -44: 这里 0.04730296647773235
# -45: 不是 0.04730296647773235
# -46: 景色 0.04730296647773235
# -47: 世界 0.04730296647773235
# -48: 店铺 0.04730296647773235
# -49: 旁边 0.04730296647773235
# -50: 古老 0.04392418315789432

# %%
data = words_A36_spec


(
    WordCloud()
    .add(series_name="A36景点特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="A36景点特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="c649a1022a1846c98d1c6984b5c7cc5c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_c649a1022a1846c98d1c6984b5c7cc5c = echarts.init(
#                     document.getElementById('c649a1022a1846c98d1c6984b5c7cc5c'), 'white', {renderer: 'canvas'});
#                 var option_c649a1022a1846c98d1c6984b5c7cc5c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "A36\u666f\u70b9\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u666f\u533a",
#                     "value": "0.46289331481780943",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(97,21,144)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9676\u74f7",
#                     "value": "0.3480146819433166",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,84,36)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.22637848242914765",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(26,37,114)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5730\u65b9",
#                     "value": "0.21624213246963359",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,25,158)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f5b\u5c71",
#                     "value": "0.18583308259109138",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(20,39,85)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u666f\u70b9",
#                     "value": "0.18245429927125334",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(83,3,101)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u503c\u5f97",
#                     "value": "0.18245429927125334",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(16,158,138)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u91cc\u9762",
#                     "value": "0.17569673263157728",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(17,35,111)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53ef\u4ee5",
#                     "value": "0.15542403271254915",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(54,51,8)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u95e8\u7968",
#                     "value": "0.15542403271254915",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,67,100)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6587\u5316",
#                     "value": "0.13853011611335903",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(2,69,83)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7279\u8272",
#                     "value": "0.13177254947368297",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(95,120,7)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u77f3\u6e7e",
#                     "value": "0.13177254947368297",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,12,76)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5386\u53f2",
#                     "value": "0.11149984955465482",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(4,51,35)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b9\u4fbf",
#                     "value": "0.10474228291497877",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(18,42,158)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u770b\u770b",
#                     "value": "0.10474228291497877",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,122,75)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u559c\u6b22",
#                     "value": "0.0946059329554647",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(154,83,38)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f88\u591a",
#                     "value": "0.09122714963562667",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(17,111,71)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4fbf\u5b9c",
#                     "value": "0.08446958299595062",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(67,38,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e00\u4e2a",
#                     "value": "0.0810907996761126",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(68,113,74)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6bd4\u8f83",
#                     "value": "0.07771201635627457",

# %%
A48 = content_med_scenic.loc[content_med_scenic['景区名称'] == 'A48']
words_A48= scenic_spot_participle(A48)
words_A48_spec = words_name(words_A48)
data = words_A48_spec
# Out:
#  72%|██████████████████████████████████████████████████████▏                    | 4647/6425 [00:00<00:00, 35304.80it/s]
# -1: 不错 0.47746472458120504
# -2: 五台山 0.33096986590288074
# -3: 取票 0.3092669238764623
# -4: 景区 0.28756398185004395
# -5: 方便 0.2658610398236255
# -6: 导游 0.2007522137443703
# -7: 地方 0.15192059418492887
# -8: 佛教 0.14106912317171966
# -9: 非常 0.13021765215851044
# -10: 门票 0.12479191665190585
# -11: 高速 0.09766323911888285
# -12: 时间 0.09223750361227824
# -13: 五爷 0.09223750361227824
# -14: 圣地 0.08681176810567363
# -15: 服务 0.08138603259906904
# -16: 值得 0.08138603259906904
# -17: 比较 0.08138603259906904
# -18: 一定 0.07053456158585983
# -19: 没有 0.07053456158585983
# -20: 讲解 0.06510882607925522
# -21: 风景 0.06510882607925522
# -22: 很多 0.06510882607925522
# -23: 需要 0.06510882607925522
# -24: 感觉 0.05968309057265063
# -25: 买票 0.05968309057265063
# -26: 价格 0.05968309057265063
# -27: 有点 0.05425735506604602
# -28: 排队 0.05425735506604602
# -29: 主要 0.05425735506604602
# -30: 景点 0.05425735506604602
# -31: 热情 0.05425735506604602
# -32: 开车 0.05425735506604602
# -33: 就是 0.05425735506604602
# -34: 索道 0.04883161955944142
# -35: 特别 0.04883161955944142
# -36: 直接 0.04883161955944142
# -37: 这次 0.04883161955944142
# -38: 一下 0.04883161955944142
# -39: 旅游 0.04340588405283682
# -40: 老人 0.04340588405283682
# -41: 便宜 0.04340588405283682
# -42: 一次 0.04340588405283682
# -43: 游玩 0.04340588405283682
# -44: 方便快捷 0.04340588405283682
# -45: 真的 0.04340588405283682
# -46: 优惠 0.04340588405283682
# -47: 游客 0.03798014854623222
# -48: 售票处 0.03798014854623222
# -49: 这里 0.03798014854623222
# -50: 不用 0.03798014854623222

# %%
data = words_A48_spec


(
    WordCloud()
    .add(series_name="A48景点特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="A48景点特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="f6ff595e3a7142f08a83bb3928d508f6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_f6ff595e3a7142f08a83bb3928d508f6 = echarts.init(
#                     document.getElementById('f6ff595e3a7142f08a83bb3928d508f6'), 'white', {renderer: 'canvas'});
#                 var option_f6ff595e3a7142f08a83bb3928d508f6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "A48\u666f\u70b9\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.47746472458120504",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,109,133)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e94\u53f0\u5c71",
#                     "value": "0.33096986590288074",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(147,124,45)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53d6\u7968",
#                     "value": "0.3092669238764623",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,40,139)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u666f\u533a",
#                     "value": "0.28756398185004395",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,128,29)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b9\u4fbf",
#                     "value": "0.2658610398236255",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(128,142,4)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5bfc\u6e38",
#                     "value": "0.2007522137443703",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(95,101,93)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5730\u65b9",
#                     "value": "0.15192059418492887",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(1,59,63)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f5b\u6559",
#                     "value": "0.14106912317171966",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(124,95,81)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": "0.13021765215851044",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(65,119,58)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u95e8\u7968",
#                     "value": "0.12479191665190585",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,148,159)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9ad8\u901f",
#                     "value": "0.09766323911888285",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,30,122)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65f6\u95f4",
#                     "value": "0.09223750361227824",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(107,15,112)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e94\u7237",
#                     "value": "0.09223750361227824",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(78,56,20)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5723\u5730",
#                     "value": "0.08681176810567363",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(101,98,58)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u670d\u52a1",
#                     "value": "0.08138603259906904",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(44,139,144)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u503c\u5f97",
#                     "value": "0.08138603259906904",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(123,95,138)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6bd4\u8f83",
#                     "value": "0.08138603259906904",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(4,5,9)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e00\u5b9a",
#                     "value": "0.07053456158585983",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(100,74,158)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ca1\u6709",
#                     "value": "0.07053456158585983",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(8,94,128)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bb2\u89e3",
#                     "value": "0.06510882607925522",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(45,84,54)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u98ce\u666f",
#                     "value": "0.0651088

# %% [markdown]
# ### 综合评价低的3个景点

# %%
content_low = content.loc[content['总得分']<4.3].sort_values('总得分',ascending=False)
content_low.head()
# Out:
#    景区名称    总得分  服务得分  位置得分  设施得分  卫生得分  性价比得分
# 42  A43  4.285   3.9   4.9   4.0   4.5    4.5
# 18  A19  4.270   3.9   4.9   4.0   4.5    4.4
# 30  A31  4.270   3.9   4.0   4.5   4.5    4.5
# 40  A41  4.260   4.0   4.2   4.1   4.5    4.5
# 23  A24  4.255   3.9   4.9   4.0   4.2    4.9

# %%
content_low_scenic = pd.read_excel(r"./附件1/景区评论.xlsx",engine='openpyxl')

# %%
A43 = content_med_scenic.loc[content_med_scenic['景区名称'] == 'A43']

# %%
words_A43= scenic_spot_participle(A43)
# Out:
#  71%|█████████████████████████████████████████████████████▏                     | 6241/8795 [00:00<00:00, 32381.86it/s]

# %%
words_A43_spec = words_name(words_A43)
# Out:
# -1: 不错 0.4464988791843111
# -2: 岛上 0.341192539754049
# -3: 度假村 0.21482493243773457
# -4: 红树林 0.20218817170610312
# -5: 码头 0.16849014308841928
# -6: 方便 0.1600656359339983
# -7: 没有 0.1600656359339983
# -8: 湛江 0.1432166216251564
# -9: 地方 0.1347921144707354
# -10: 值得 0.1347921144707354
# -11: 景色 0.12215535373910397
# -12: 比较 0.1179431001618935
# -13: 温泉 0.10951859300747252
# -14: 没什么 0.10951859300747252
# -15: 沙滩 0.10530633943026205
# -16: 门票 0.10530633943026205
# -17: 环境 0.10530633943026205
# -18: 一个 0.10109408585305156
# -19: 景点 0.10109408585305156
# -20: 很多 0.10109408585305156
# -21: 度假 0.10109408585305156
# -22: 风景 0.09688183227584109
# -23: 船票 0.09688183227584109
# -24: 开发 0.0926695786986306
# -25: 电瓶车 0.0926695786986306
# -26: 可以 0.0926695786986306
# -27: 非常 0.0926695786986306
# -28: 小岛 0.08845732512142011
# -29: 好玩 0.08424507154420964
# -30: 取票 0.08003281796699915
# -31: 坐船 0.08003281796699915
# -32: 适合 0.07582056438978867
# -33: 感觉 0.07582056438978867
# -34: 过去 0.0716083108125782
# -35: 景区 0.0716083108125782
# -36: 便宜 0.0716083108125782
# -37: 游玩 0.0716083108125782
# -38: 小时 0.0673960572353677
# -39: 休闲 0.0673960572353677
# -40: 特别 0.0673960572353677
# -41: 自行车 0.06318380365815722
# -42: 一圈 0.06318380365815722
# -43: 选择 0.05897155008094675
# -44: 海滨 0.05897155008094675
# -45: 里面 0.05897155008094675
# -46: 不是 0.05475929650373626
# -47: 设施 0.05475929650373626
# -48: 50 0.05475929650373626
# -49: 服务 0.05054704292652578
# -50: 不过 0.05054704292652578

# %%
data = words_A43_spec

(
    WordCloud()
    .add(series_name="A43景点特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="A43景点特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="1bfc7a50a2794d26a637db11ec3643dd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_1bfc7a50a2794d26a637db11ec3643dd = echarts.init(
#                     document.getElementById('1bfc7a50a2794d26a637db11ec3643dd'), 'white', {renderer: 'canvas'});
#                 var option_1bfc7a50a2794d26a637db11ec3643dd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "A43\u666f\u70b9\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.4464988791843111",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(44,153,120)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c9b\u4e0a",
#                     "value": "0.341192539754049",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(23,21,92)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5ea6\u5047\u6751",
#                     "value": "0.21482493243773457",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(121,48,75)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7ea2\u6811\u6797",
#                     "value": "0.20218817170610312",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(20,137,152)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7801\u5934",
#                     "value": "0.16849014308841928",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(22,25,113)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b9\u4fbf",
#                     "value": "0.1600656359339983",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(151,125,90)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ca1\u6709",
#                     "value": "0.1600656359339983",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(116,54,132)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6e5b\u6c5f",
#                     "value": "0.1432166216251564",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(38,154,111)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5730\u65b9",
#                     "value": "0.1347921144707354",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,69,30)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u503c\u5f97",
#                     "value": "0.1347921144707354",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,132,89)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u666f\u8272",
#                     "value": "0.12215535373910397",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(67,98,65)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6bd4\u8f83",
#                     "value": "0.1179431001618935",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(153,153,148)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6e29\u6cc9",
#                     "value": "0.10951859300747252",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(43,37,10)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ca1\u4ec0\u4e48",
#                     "value": "0.10951859300747252",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(160,17,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6c99\u6ee9",
#                     "value": "0.10530633943026205",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(16,90,66)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u95e8\u7968",
#                     "value": "0.10530633943026205",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(17,113,27)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73af\u5883",
#                     "value": "0.10530633943026205",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(140,43,136)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e00\u4e2a",
#                     "value": "0.10109408585305156",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,101,142)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u666f\u70b9",
#                     "value": "0.10109408585305156",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(54,114,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f88\u591a",
#                     "value": "0.10109408585305156",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(82,68,118)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5ea6\u5047",
#                     "value"

# %%
A19 = content_med_scenic.loc[content_med_scenic['景区名称'] == 'A19']
words_A19= scenic_spot_participle(A19)
words_A19_spec = words_name(words_A19)
data = words_A19_spec
# Out:
#  71%|████████████████████████████████████████████████████                     | 16217/22748 [00:00<00:00, 16659.54it/s]
# -1: 不错 0.41975597627526356
# -2: 风景 0.23041923804046385
# -3: 值得 0.21612967289066765
# -4: 景色 0.21612967289066765
# -5: 方便 0.21255728160321857
# -6: 湖水 0.19826771645342237
# -7: 非常 0.19469532516597332
# -8: 景点 0.17504717308500353
# -9: 取票 0.16432999922265637
# -10: 游船 0.15897141229148282
# -11: 没有 0.1446818471416866
# -12: 游玩 0.12681989070444133
# -13: 三个 0.12681989070444133
# -14: 空气 0.12324749941699228
# -15: 岛上 0.12324749941699228
# -16: 坐船 0.11610271684209418
# -17: 感觉 0.11610271684209418
# -18: 环境 0.10717173862347155
# -19: 地方 0.10717173862347155
# -20: 景区 0.1035993473360225
# -21: 没什么 0.09824076040484893
# -22: 有点 0.09824076040484893
# -23: 就是 0.09645456476112439
# -24: 小时 0.09466836911739987
# -25: 比较 0.09109597782995082
# -26: 适合 0.08930978218622629
# -27: 清澈 0.08752358654250177
# -28: 门票 0.08573739089877724
# -29: 时间 0.08573739089877724
# -30: 好玩 0.08216499961132818
# -31: 可以 0.07680641268015462
# -32: 小岛 0.07323402139270556
# -33: 真的 0.07144782574898104
# -34: 开发 0.07144782574898104
# -35: 很大 0.06966163010525651
# -36: 价格 0.06787543446153198
# -37: 水质 0.06608923881780746
# -38: 便宜 0.06608923881780746
# -39: 很多 0.06430304317408293
# -40: 河源 0.06430304317408293
# -41: 设施 0.06073065188663388
# -42: 时候 0.05894445624290935
# -43: 天气 0.05894445624290935
# -44: 但是 0.05715826059918483
# -45: 性价比 0.05715826059918483
# -46: 镜花缘 0.05715826059918483
# -47: 特别 0.0553720649554603
# -48: 很漂亮 0.05358586931173578
# -49: 一次 0.05179967366801125
# -50: 舒服 0.050013478024286726

# %%
(
    WordCloud()
    .add(series_name="A19景点特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="A19景点特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="94a6000d471c464889c50d3de51307c0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_94a6000d471c464889c50d3de51307c0 = echarts.init(
#                     document.getElementById('94a6000d471c464889c50d3de51307c0'), 'white', {renderer: 'canvas'});
#                 var option_94a6000d471c464889c50d3de51307c0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "A19\u666f\u70b9\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.41975597627526356",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(158,96,113)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u98ce\u666f",
#                     "value": "0.23041923804046385",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(6,147,40)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u503c\u5f97",
#                     "value": "0.21612967289066765",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,1,7)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u666f\u8272",
#                     "value": "0.21612967289066765",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(133,140,34)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b9\u4fbf",
#                     "value": "0.21255728160321857",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(96,56,69)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6e56\u6c34",
#                     "value": "0.19826771645342237",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(7,0,35)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": "0.19469532516597332",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,69,26)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u666f\u70b9",
#                     "value": "0.17504717308500353",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(115,135,138)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53d6\u7968",
#                     "value": "0.16432999922265637",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(108,122,80)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6e38\u8239",
#                     "value": "0.15897141229148282",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(26,158,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ca1\u6709",
#                     "value": "0.1446818471416866",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(4,131,128)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6e38\u73a9",
#                     "value": "0.12681989070444133",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(40,57,6)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e09\u4e2a",
#                     "value": "0.12681989070444133",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(71,62,72)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7a7a\u6c14",
#                     "value": "0.12324749941699228",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(131,38,45)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c9b\u4e0a",
#                     "value": "0.12324749941699228",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(127,17,45)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5750\u8239",
#                     "value": "0.11610271684209418",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(151,148,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u611f\u89c9",
#                     "value": "0.11610271684209418",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(11,10,36)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73af\u5883",
#                     "value": "0.10717173862347155",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(114,63,114)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5730\u65b9",
#                     "value": "0.10717173862347155",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(16,92,8)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u666f\u533a",
#                     "value": "0.1035993473360225",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(18,24,131)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ca1\u4ec0\u4e48",
#                     "value": "0.0982407604048

# %%
A31 = content_med_scenic.loc[content_med_scenic['景区名称'] == 'A31']
words_A31= scenic_spot_participle(A19)
words_A31_spec = words_name(words_A19)
data = words_A31_spec
# Out:
#  71%|████████████████████████████████████████████████████                     | 16217/22748 [00:00<00:00, 17353.62it/s]
# -1: 不错 0.41975597627526356
# -2: 风景 0.23041923804046385
# -3: 值得 0.21612967289066765
# -4: 景色 0.21612967289066765
# -5: 方便 0.21255728160321857
# -6: 湖水 0.19826771645342237
# -7: 非常 0.19469532516597332
# -8: 景点 0.17504717308500353
# -9: 取票 0.16432999922265637
# -10: 游船 0.15897141229148282
# -11: 没有 0.1446818471416866
# -12: 游玩 0.12681989070444133
# -13: 三个 0.12681989070444133
# -14: 空气 0.12324749941699228
# -15: 岛上 0.12324749941699228
# -16: 坐船 0.11610271684209418
# -17: 感觉 0.11610271684209418
# -18: 环境 0.10717173862347155
# -19: 地方 0.10717173862347155
# -20: 景区 0.1035993473360225
# -21: 没什么 0.09824076040484893
# -22: 有点 0.09824076040484893
# -23: 就是 0.09645456476112439
# -24: 小时 0.09466836911739987
# -25: 比较 0.09109597782995082
# -26: 适合 0.08930978218622629
# -27: 清澈 0.08752358654250177
# -28: 门票 0.08573739089877724
# -29: 时间 0.08573739089877724
# -30: 好玩 0.08216499961132818
# -31: 可以 0.07680641268015462
# -32: 小岛 0.07323402139270556
# -33: 真的 0.07144782574898104
# -34: 开发 0.07144782574898104
# -35: 很大 0.06966163010525651
# -36: 价格 0.06787543446153198
# -37: 水质 0.06608923881780746
# -38: 便宜 0.06608923881780746
# -39: 很多 0.06430304317408293
# -40: 河源 0.06430304317408293
# -41: 设施 0.06073065188663388
# -42: 时候 0.05894445624290935
# -43: 天气 0.05894445624290935
# -44: 但是 0.05715826059918483
# -45: 性价比 0.05715826059918483
# -46: 镜花缘 0.05715826059918483
# -47: 特别 0.0553720649554603
# -48: 很漂亮 0.05358586931173578
# -49: 一次 0.05179967366801125
# -50: 舒服 0.050013478024286726

# %%
(
    WordCloud()
    .add(series_name="A31景点特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="A31景点特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="0cf4852ed76e472ea51276f3e0d90e9f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_0cf4852ed76e472ea51276f3e0d90e9f = echarts.init(
#                     document.getElementById('0cf4852ed76e472ea51276f3e0d90e9f'), 'white', {renderer: 'canvas'});
#                 var option_0cf4852ed76e472ea51276f3e0d90e9f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "A31\u666f\u70b9\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.41975597627526356",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,151,155)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u98ce\u666f",
#                     "value": "0.23041923804046385",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,135,2)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u503c\u5f97",
#                     "value": "0.21612967289066765",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(11,19,99)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u666f\u8272",
#                     "value": "0.21612967289066765",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(34,3,51)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b9\u4fbf",
#                     "value": "0.21255728160321857",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(5,84,123)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6e56\u6c34",
#                     "value": "0.19826771645342237",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,30,51)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": "0.19469532516597332",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(141,109,62)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u666f\u70b9",
#                     "value": "0.17504717308500353",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(137,102,42)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53d6\u7968",
#                     "value": "0.16432999922265637",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(73,63,117)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6e38\u8239",
#                     "value": "0.15897141229148282",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(117,60,16)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ca1\u6709",
#                     "value": "0.1446818471416866",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,29,76)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6e38\u73a9",
#                     "value": "0.12681989070444133",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(61,82,151)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e09\u4e2a",
#                     "value": "0.12681989070444133",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(119,158,10)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7a7a\u6c14",
#                     "value": "0.12324749941699228",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(13,136,98)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c9b\u4e0a",
#                     "value": "0.12324749941699228",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,64,24)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5750\u8239",
#                     "value": "0.11610271684209418",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(41,64,16)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u611f\u89c9",
#                     "value": "0.11610271684209418",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(77,90,107)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73af\u5883",
#                     "value": "0.10717173862347155",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,125,6)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5730\u65b9",
#                     "value": "0.10717173862347155",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,46,94)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u666f\u533a",
#                     "value": "0.1035993473360225",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(98,154,114)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ca1\u4ec0\u4e48",
#                     "value": "0.0982407

# %% [markdown]
# ## (2、)综合评价酒店的高中低特色

# %%
content_hotel_score = pd.read_excel(r"./附件2/酒店评分.xlsx",engine='openpyxl')  
content_hotel_score.head()
# Out:
#    序号 酒店名称  总得分  服务得分  位置得分  设施得分  卫生得分  性价比得分
# 0   1  H01  4.8   4.8   4.8   4.7   4.8    4.0
# 1   2  H02  4.7   4.7   4.8   4.6   4.7    4.0
# 2   3  H03  4.8   4.8   4.8   4.8   4.9    4.0
# 3   4  H04  4.9   4.9   4.9   4.9   4.9    4.0
# 4   5  H05  4.7   4.7   4.8   4.7   4.8    4.0

# %%
content_hotel = pd.read_excel(r"./附件1/酒店评论.xlsx",engine='openpyxl')  
content_hotel.head()
# Out:
#   酒店名称        评论日期                                               评论内容  入住房型
# 0  H01  2020-01-01                                          酒店很适合家庭出行  标准客房
# 1  H01  2020-01-01                                      升级了房间 延迟退房 很赞  标准客房
# 2  H01  2020-01-01  这几年，每年都会来广州，每次都会住**酒店。因为位置好，酒店的性价比也不错，这次给免费升级了...  标准客房
# 3  H01  2020-01-01                                             酒店很好不错  标准客房
# 4  H01  2020-01-01                                              超五星好评  高级客房

# %% [markdown]
# ## 高评分的酒店特色

# %%
#找出综合评分高于4.6的景点
content_hotel_high = content_hotel_score.loc[content_hotel_score['总得分']>4.6].sort_values('总得分',ascending=False)
content_hotel_high.head()
# Out:
#     序号 酒店名称  总得分  服务得分  位置得分  设施得分  卫生得分  性价比得分
# 12  13  H13  4.9   4.9   4.9   4.8   4.9    4.2
# 3    4  H04  4.9   4.9   4.9   4.9   4.9    4.0
# 5    6  H06  4.9   4.9   4.9   4.8   4.9    4.3
# 6    7  H07  4.9   4.8   4.9   4.8   4.9    4.0
# 36  37  H37  4.9   4.9   4.9   4.9   4.9    4.0

# %%
H13 = content_hotel.loc[content_hotel['酒店名称'] == 'H13']
words_H13= scenic_spot_participle(H13)
words_H13_spec = words_name(words_H13)
data = words_H13_spec
# Out:
#  71%|███████████████████████████████████████████████████▌                     | 22699/32164 [00:01<00:00, 12707.58it/s]
# -1: 酒店 0.7247799493664373
# -2: 服务 0.33311392869352635
# -3: 非常 0.20255858846922267
# -4: 房间 0.18989867668989624
# -5: 入住 0.1574576527553723
# -6: 早餐 0.1384677850863827
# -7: 经理 0.13292907368292736
# -8: 特别 0.10760925012427454
# -9: 不错 0.10602676115185873
# -10: 我们 0.09653182731736393
# -11: 贴心 0.08782813796907701
# -12: 孩子 0.08545440451045332
# -13: 下次 0.0822894265656217
# -14: 大桥 0.0783332041345822
# -15: 升级 0.0759594706759585
# -16: 环境 0.0735857372173348
# -17: 体验 0.06804702581387949
# -18: 位置 0.06725578132767158
# -19: 真的 0.06567329235525578
# -20: 看到 0.06329955889663208
# -21: 港珠澳 0.06013458095180048
# -22: 水果 0.06013458095180048
# -23: 前台 0.06013458095180048
# -24: 热情 0.059343336465592575
# -25: 海景房 0.057760847493176774
# -26: 安排 0.057760847493176774
# -27: 推荐 0.05696960300696887
# -28: 海景 0.05538711403455307
# -29: 选择 0.053013380575929366
# -30: 大堂 0.051430891603513565
# -31: 超级 0.048265913658681964
# -32: 免费 0.04668342468626616
# -33: 感觉 0.045100935713850356
# -34: 长隆 0.04430969122764246
# -35: 感谢 0.04114471328281085
# -36: 这次 0.04114471328281085
# -37: 这家 0.040353468796602954
# -38: 准备 0.040353468796602954
# -39: 设施 0.03956222431039505
# -40: 满意 0.03877097982418715
# -41: 可以 0.03877097982418715
# -42: 很多 0.03797973533797925
# -43: 还会 0.03797973533797925
# -44: 喜欢 0.037188490851771346
# -45: 情侣 0.03639724636556345
# -46: 周到 0.03639724636556345
# -47: 小朋友 0.03639724636556345
# -48: 丰富 0.035606001879355545
# -49: 没有 0.035606001879355545
# -50: 方便 0.03481475739314765

# %%
(
    WordCloud()
    .add(series_name="H13酒店特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="H13酒店特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="222c0dbd53a14b6aa89b402a61a008fb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_222c0dbd53a14b6aa89b402a61a008fb = echarts.init(
#                     document.getElementById('222c0dbd53a14b6aa89b402a61a008fb'), 'white', {renderer: 'canvas'});
#                 var option_222c0dbd53a14b6aa89b402a61a008fb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "H13\u9152\u5e97\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u9152\u5e97",
#                     "value": "0.7247799493664373",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(46,67,7)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u670d\u52a1",
#                     "value": "0.33311392869352635",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(16,143,152)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": "0.20255858846922267",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,38,89)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u623f\u95f4",
#                     "value": "0.18989867668989624",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,46,55)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5165\u4f4f",
#                     "value": "0.1574576527553723",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(84,95,93)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65e9\u9910",
#                     "value": "0.1384677850863827",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(50,31,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7ecf\u7406",
#                     "value": "0.13292907368292736",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(93,76,82)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7279\u522b",
#                     "value": "0.10760925012427454",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(76,128,135)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.10602676115185873",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(68,74,107)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6211\u4eec",
#                     "value": "0.09653182731736393",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(1,85,100)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8d34\u5fc3",
#                     "value": "0.08782813796907701",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(91,59,106)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b69\u5b50",
#                     "value": "0.08545440451045332",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(73,52,65)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0b\u6b21",
#                     "value": "0.0822894265656217",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,89,110)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5927\u6865",
#                     "value": "0.0783332041345822",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(32,134,56)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5347\u7ea7",
#                     "value": "0.0759594706759585",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(97,71,71)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73af\u5883",
#                     "value": "0.0735857372173348",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(85,55,29)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f53\u9a8c",
#                     "value": "0.06804702581387949",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(22,9,9)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f4d\u7f6e",
#                     "value": "0.06725578132767158",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,113,75)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u771f\u7684",
#                     "value": "0.06567329235525578",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,66,92)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u770b\u5230",
#                     "value": "0.06329955889663208",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,134,128)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6e2f\u73e0\u6fb3",
#                     "value": "0.06013458095180048

# %%
H04 = content_hotel.loc[content_hotel['酒店名称'] == 'H04']
words_H04= scenic_spot_participle(H04)
words_H04_spec = words_name(words_H04)
data = words_H04_spec
# Out:
#  72%|████████████████████████████████████████████████████▊                    | 18171/25102 [00:01<00:00, 16239.07it/s]
# -1: 酒店 0.46519187172975135
# -2: 服务 0.33862415483907915
# -3: 不错 0.32308075101040007
# -4: 非常 0.275340296393743
# -5: 温泉 0.2609071356956839
# -6: 环境 0.1976232772503478
# -7: 孩子 0.17652865776856913
# -8: 房间 0.1509930657643107
# -9: 早餐 0.14544185011121102
# -10: 适合 0.129898446282532
# -11: 入住 0.11768577184571274
# -12: 下次 0.11324479932323302
# -13: 开心 0.11102431306199316
# -14: 小朋友 0.10658334053951343
# -15: 泳池 0.10103212488641378
# -16: 很多 0.09326042297207425
# -17: 特别 0.09326042297207425
# -18: 亲子 0.09215017984145432
# -19: 喜欢 0.08992969358021445
# -20: 设施 0.08659896418835467
# -21: 方便 0.0843784779271148
# -22: 比较 0.08104774853525501
# -23: 体验 0.07882726227401514
# -24: 还会 0.07771701914339521
# -25: 前台 0.07549653288215535
# -26: 小孩 0.06883507409843576
# -27: 满意 0.06772483096781583
# -28: 贴心 0.06217361531471617
# -29: 可以 0.061063372184096236
# -30: 水上 0.05995312905347631
# -31: 丰富 0.05995312905347631
# -32: 很棒 0.054401913400376645
# -33: 干净 0.053291670269756716
# -34: 地方 0.05218142713913678
# -35: 很大 0.05107118400851685
# -36: 推荐 0.049960940877896924
# -37: 乐园 0.049960940877896924
# -38: 度假 0.04885069774727699
# -39: 玩水 0.04774045461665706
# -40: 深圳 0.04774045461665706
# -41: 一次 0.046630211486037125
# -42: 热情 0.0455199683554172
# -43: 值得 0.04440972522479726
# -44: 池畔 0.04329948209417733
# -45: 经理 0.04329948209417733
# -46: 大堂 0.04107899583293747
# -47: 阳台 0.04107899583293747
# -48: 感觉 0.04107899583293747
# -49: 没有 0.04107899583293747
# -50: 舒服 0.039968752702317534

# %%
(
    WordCloud()
    .add(series_name="H04酒店特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="H04酒店特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="6bc7d32dd3be4866b1f809a435f9ec4c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_6bc7d32dd3be4866b1f809a435f9ec4c = echarts.init(
#                     document.getElementById('6bc7d32dd3be4866b1f809a435f9ec4c'), 'white', {renderer: 'canvas'});
#                 var option_6bc7d32dd3be4866b1f809a435f9ec4c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "H04\u9152\u5e97\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u9152\u5e97",
#                     "value": "0.46519187172975135",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(12,149,3)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u670d\u52a1",
#                     "value": "0.33862415483907915",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(156,100,66)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.32308075101040007",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(65,157,90)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": "0.275340296393743",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(78,25,45)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6e29\u6cc9",
#                     "value": "0.2609071356956839",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(98,114,16)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73af\u5883",
#                     "value": "0.1976232772503478",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,28,27)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b69\u5b50",
#                     "value": "0.17652865776856913",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(36,108,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u623f\u95f4",
#                     "value": "0.1509930657643107",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(158,12,142)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65e9\u9910",
#                     "value": "0.14544185011121102",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,154,50)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9002\u5408",
#                     "value": "0.129898446282532",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(112,81,101)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5165\u4f4f",
#                     "value": "0.11768577184571274",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(89,93,100)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0b\u6b21",
#                     "value": "0.11324479932323302",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(117,39,63)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f00\u5fc3",
#                     "value": "0.11102431306199316",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(62,118,21)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c0f\u670b\u53cb",
#                     "value": "0.10658334053951343",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(149,2,21)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6cf3\u6c60",
#                     "value": "0.10103212488641378",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(132,96,79)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f88\u591a",
#                     "value": "0.09326042297207425",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(39,80,50)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7279\u522b",
#                     "value": "0.09326042297207425",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(32,136,54)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4eb2\u5b50",
#                     "value": "0.09215017984145432",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(3,108,25)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u559c\u6b22",
#                     "value": "0.08992969358021445",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(125,46,101)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bbe\u65bd",
#                     "value": "0.08659896418835467",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(142,48,52)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b9\u4fbf",
#                     "value": "0.084378477927

# %%
H06 = content_hotel.loc[content_hotel['酒店名称'] == 'H06']
words_H06= scenic_spot_participle(H06)
words_H06_spec = words_name(words_H06)
data = words_H06_spec
# Out:
#  71%|███████████████████████████████████████████████████▋                     | 19362/27354 [00:01<00:00, 15420.01it/s]
# -1: 服务 0.4643210252745661
# -2: 温泉 0.4084305314915165
# -3: 酒店 0.36973711271863596
# -4: 非常 0.29235027517287493
# -5: 不错 0.22141234075592733
# -6: 早餐 0.16982111572542
# -7: 房间 0.16767148134914886
# -8: 环境 0.1515492235271153
# -9: 孩子 0.11715507350677709
# -10: 干净 0.11393062194237039
# -11: 喜欢 0.0956587297440657
# -12: 设施 0.09243427817965899
# -13: 特别 0.09135946099152342
# -14: 服务员 0.0881350094271167
# -15: 感觉 0.08706019223898114
# -16: 入住 0.08276092348643886
# -17: 很多 0.07846165473389659
# -18: 服务态度 0.07846165473389659
# -19: 丰富 0.0741623859813543
# -20: 小朋友 0.0709379344169476
# -21: 下次 0.0709379344169476
# -22: 泡温泉 0.0709379344169476
# -23: 体验 0.06771348285254089
# -24: 工作人员 0.06556384847626975
# -25: 比较 0.062339396911863035
# -26: 适合 0.05911494534745633
# -27: 卫生 0.05696531097118519
# -28: 一次 0.05589049378304962
# -29: 没有 0.05589049378304962
# -30: 开心 0.05481567659491405
# -31: 舒服 0.05481567659491405
# -32: 人员 0.051591225030507344
# -33: 真的 0.051591225030507344
# -34: 还有 0.051591225030507344
# -35: 热情 0.05051640784237177
# -36: 我们 0.0494415906542362
# -37: 流溪河 0.04836677346610063
# -38: 小孩 0.04836677346610063
# -39: 有点 0.047291956277965064
# -40: 方便 0.046217139089829495
# -41: 贴心 0.04514232190169393
# -42: 泳池 0.04406750471355835
# -43: 儿童 0.04299268752542278
# -44: 满意 0.041917870337287215
# -45: 值得 0.041917870337287215
# -46: 度假 0.041917870337287215
# -47: 地方 0.041917870337287215
# -48: 品种 0.04084305314915165
# -49: 免费 0.04084305314915165
# -50: 一个 0.04084305314915165

# %%
(
    WordCloud()
    .add(series_name="H06酒店特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="H06酒店特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="cb67aecb8aca43c0a78a3e60096ba259" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_cb67aecb8aca43c0a78a3e60096ba259 = echarts.init(
#                     document.getElementById('cb67aecb8aca43c0a78a3e60096ba259'), 'white', {renderer: 'canvas'});
#                 var option_cb67aecb8aca43c0a78a3e60096ba259 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "H06\u9152\u5e97\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u670d\u52a1",
#                     "value": "0.4643210252745661",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(6,19,118)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6e29\u6cc9",
#                     "value": "0.4084305314915165",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(107,158,34)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9152\u5e97",
#                     "value": "0.36973711271863596",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,122,133)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": "0.29235027517287493",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(28,38,142)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.22141234075592733",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(91,153,17)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65e9\u9910",
#                     "value": "0.16982111572542",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(83,157,44)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u623f\u95f4",
#                     "value": "0.16767148134914886",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(40,33,87)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73af\u5883",
#                     "value": "0.1515492235271153",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(76,91,131)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b69\u5b50",
#                     "value": "0.11715507350677709",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(99,115,6)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e72\u51c0",
#                     "value": "0.11393062194237039",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(69,154,81)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u559c\u6b22",
#                     "value": "0.0956587297440657",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(113,155,155)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bbe\u65bd",
#                     "value": "0.09243427817965899",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(31,130,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7279\u522b",
#                     "value": "0.09135946099152342",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(8,99,92)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u670d\u52a1\u5458",
#                     "value": "0.0881350094271167",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(146,158,108)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u611f\u89c9",
#                     "value": "0.08706019223898114",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(154,34,14)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5165\u4f4f",
#                     "value": "0.08276092348643886",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(146,87,88)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f88\u591a",
#                     "value": "0.07846165473389659",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(105,18,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u670d\u52a1\u6001\u5ea6",
#                     "value": "0.07846165473389659",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(62,79,15)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e30\u5bcc",
#                     "value": "0.0741623859813543",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(128,73,123)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c0f\u670b\u53cb",
#                     "value": "0.0709379344169476",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,100,141)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0b\u6b21",
#                     "valu

# %% [markdown]
# ## 中评分的酒店特色

# %%
content_hotel_med = content_hotel_score.loc[(4.3<=content_hotel_score['总得分']) & (content_hotel_score['总得分']<=4.6)].sort_values('总得分',ascending=False)
content_hotel_med.head()
# Out:
#     序号 酒店名称  总得分  服务得分  位置得分  设施得分  卫生得分  性价比得分
# 17  18  H18  4.6   4.6   4.7   4.5   4.7    4.0
# 25  26  H26  4.6   4.6   4.7   4.5   4.6    4.0
# 26  27  H27  4.6   4.6   4.7   4.5   4.7    4.0
# 28  29  H29  4.6   4.7   4.8   4.7   4.6    4.1
# 32  33  H33  4.6   4.5   4.7   4.4   4.6    4.0

# %%
H18 = content_hotel.loc[content_hotel['酒店名称'] == 'H18']
words_H18= scenic_spot_participle(H18)
words_H18_spec = words_name(words_H18)
data = words_H18_spec
# Out:
#  74%|██████████████████████████████████████████████████████▍                   | 8320/11309 [00:00<00:00, 29271.11it/s]
# -1: 酒店 0.4283352937730962
# -2: 不错 0.42344003327283225
# -3: 房间 0.32308719301742117
# -4: 早餐 0.31084904176676126
# -5: 位置 0.22028672251187806
# -6: 服务 0.21783909226174608
# -7: 非常 0.20804857126121817
# -8: 方便 0.18846752926016233
# -9: 入住 0.13951492425752277
# -10: 环境 0.12727677300686288
# -11: 设施 0.11503862175620298
# -12: 前台 0.10524810075567508
# -13: 有点 0.09300994950501518
# -14: 丰富 0.08321942850448727
# -15: 比较 0.08077179825435529
# -16: 花城 0.07342890750395935
# -17: 广州 0.07342890750395935
# -18: 干净 0.07342890750395935
# -19: 舒服 0.07098127725382737
# -20: 广场 0.0685336470036954
# -21: 还好 0.06363838650343144
# -22: 没有 0.06119075625329946
# -23: 交通 0.05874312600316748
# -24: 疫情 0.0562954957530355
# -25: 感觉 0.0562954957530355
# -26: 设计 0.0562954957530355
# -27: 出差 0.053847865502903526
# -28: 体验 0.05140023525277155
# -29: 性价比 0.05140023525277155
# -30: 新城 0.048952605002639565
# -31: 就是 0.048952605002639565
# -32: 下次 0.048952605002639565
# -33: 珠江 0.048952605002639565
# -34: 卫生 0.04650497475250759
# -35: 特别 0.04650497475250759
# -36: 22 0.04650497475250759
# -37: 期间 0.04650497475250759
# -38: 满意 0.04405734450237561
# -39: 但是 0.04405734450237561
# -40: 选择 0.041609714252243635
# -41: 可以 0.03916208400211165
# -42: 便利 0.03916208400211165
# -43: 楼层 0.03916208400211165
# -44: 地理位置 0.03916208400211165
# -45: 晚上 0.03916208400211165
# -46: 味道 0.036714453751979674
# -47: 布局 0.036714453751979674
# -48: 电梯 0.036714453751979674
# -49: 舒适 0.036714453751979674
# -50: 服务态度 0.036714453751979674

# %%
(
    WordCloud()
    .add(series_name="H18酒店特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="H18酒店特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="88cc67578f3943fc825e0acd66404dd1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_88cc67578f3943fc825e0acd66404dd1 = echarts.init(
#                     document.getElementById('88cc67578f3943fc825e0acd66404dd1'), 'white', {renderer: 'canvas'});
#                 var option_88cc67578f3943fc825e0acd66404dd1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "H18\u9152\u5e97\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u9152\u5e97",
#                     "value": "0.4283352937730962",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(127,116,100)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.42344003327283225",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(87,142,149)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u623f\u95f4",
#                     "value": "0.32308719301742117",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(17,114,134)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65e9\u9910",
#                     "value": "0.31084904176676126",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,105,71)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f4d\u7f6e",
#                     "value": "0.22028672251187806",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(36,44,25)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u670d\u52a1",
#                     "value": "0.21783909226174608",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(125,58,27)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": "0.20804857126121817",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(59,57,47)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b9\u4fbf",
#                     "value": "0.18846752926016233",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(125,116,4)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5165\u4f4f",
#                     "value": "0.13951492425752277",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(150,76,54)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73af\u5883",
#                     "value": "0.12727677300686288",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(36,18,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bbe\u65bd",
#                     "value": "0.11503862175620298",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(79,51,63)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u524d\u53f0",
#                     "value": "0.10524810075567508",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(118,104,25)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6709\u70b9",
#                     "value": "0.09300994950501518",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(68,62,20)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e30\u5bcc",
#                     "value": "0.08321942850448727",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(137,136,37)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6bd4\u8f83",
#                     "value": "0.08077179825435529",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(160,148,155)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u82b1\u57ce",
#                     "value": "0.07342890750395935",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,60,157)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": "0.07342890750395935",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(44,55,56)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e72\u51c0",
#                     "value": "0.07342890750395935",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(110,122,44)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8212\u670d",
#                     "value": "0.07098127725382737",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(40,147,54)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e7f\u573a",
#                     "value": "0.0685336470036954",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(71,62,81)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fd8\u597d",
#                     "value": "0.0636383865

# %%
H26 = content_hotel.loc[content_hotel['酒店名称'] == 'H26']
words_H26= scenic_spot_participle(H26)
words_H26_spec = words_name(words_H26)
data = words_H26_spec
# Out:
#  74%|███████████████████████████████████████████████████████▏                   | 6434/8741 [00:00<00:00, 30867.17it/s]
# -1: 酒店 0.5861304342130551
# -2: 不错 0.34462298678267594
# -3: 服务 0.31477375170701105
# -4: 非常 0.24422101425543963
# -5: 房间 0.20894464552965392
# -6: 方便 0.19266324457929127
# -7: 前台 0.1872361109291704
# -8: 早餐 0.14653260855326378
# -9: 交通 0.13567834125302203
# -10: 入住 0.13296477442796156
# -11: 位置 0.11396980665253849
# -12: 设施 0.09768840570217585
# -13: 比较 0.08954770522699453
# -14: 出差 0.08683413840193409
# -15: 经理 0.08683413840193409
# -16: 没有 0.08140700475181321
# -17: 便利 0.08140700475181321
# -18: 环境 0.07869343792675276
# -19: 有点 0.06512560380145056
# -20: 热情 0.062412036976390126
# -21: 性价比 0.062412036976390126
# -22: 深圳 0.05969847015132969
# -23: 感觉 0.056984903326269244
# -24: 小朱 0.056984903326269244
# -25: 感谢 0.056984903326269244
# -26: 下次 0.056984903326269244
# -27: 大堂 0.056984903326269244
# -28: 价格 0.05427133650120881
# -29: 丰富 0.048844202851087926
# -30: 体验 0.048844202851087926
# -31: 地铁站 0.04613063602602749
# -32: 舒适 0.043417069200967044
# -33: 选择 0.04070350237590661
# -34: 干净 0.04070350237590661
# -35: 老旧 0.04070350237590661
# -36: 特别 0.04070350237590661
# -37: 疫情 0.04070350237590661
# -38: 可以 0.03798993555084616
# -39: 值班 0.03798993555084616
# -40: 服务态度 0.03798993555084616
# -41: 装修 0.03798993555084616
# -42: emily 0.03798993555084616
# -43: 陈旧 0.03798993555084616
# -44: 地理位置 0.035276368725785726
# -45: 很多 0.035276368725785726
# -46: 出行 0.035276368725785726
# -47: 五星 0.035276368725785726
# -48: 地铁 0.03256280190072528
# -49: 推荐 0.03256280190072528
# -50: 服务员 0.03256280190072528

# %%
(
    WordCloud()
    .add(series_name="H26酒店特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="H26酒店特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="2be7f1efcb5e46af9b06e567afb4b055" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_2be7f1efcb5e46af9b06e567afb4b055 = echarts.init(
#                     document.getElementById('2be7f1efcb5e46af9b06e567afb4b055'), 'white', {renderer: 'canvas'});
#                 var option_2be7f1efcb5e46af9b06e567afb4b055 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "H26\u9152\u5e97\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u9152\u5e97",
#                     "value": "0.5861304342130551",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(93,59,64)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.34462298678267594",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(18,144,110)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u670d\u52a1",
#                     "value": "0.31477375170701105",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(5,98,145)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": "0.24422101425543963",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(159,21,130)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u623f\u95f4",
#                     "value": "0.20894464552965392",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(59,13,122)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b9\u4fbf",
#                     "value": "0.19266324457929127",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(5,44,149)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u524d\u53f0",
#                     "value": "0.1872361109291704",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(42,108,101)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65e9\u9910",
#                     "value": "0.14653260855326378",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(117,84,143)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4ea4\u901a",
#                     "value": "0.13567834125302203",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(68,26,103)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5165\u4f4f",
#                     "value": "0.13296477442796156",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(12,46,153)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f4d\u7f6e",
#                     "value": "0.11396980665253849",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(23,35,78)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bbe\u65bd",
#                     "value": "0.09768840570217585",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(63,18,36)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6bd4\u8f83",
#                     "value": "0.08954770522699453",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(60,112,9)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u51fa\u5dee",
#                     "value": "0.08683413840193409",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(141,108,154)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7ecf\u7406",
#                     "value": "0.08683413840193409",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(115,85,122)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ca1\u6709",
#                     "value": "0.08140700475181321",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(132,157,62)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4fbf\u5229",
#                     "value": "0.08140700475181321",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(84,94,19)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73af\u5883",
#                     "value": "0.07869343792675276",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(42,125,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6709\u70b9",
#                     "value": "0.06512560380145056",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(94,21,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u70ed\u60c5",
#                     "value": "0.062412036976390126",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(74,1,40)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6027\u4ef7\u6bd4",
#                     "value": "0.0624120

# %%
H27 = content_hotel.loc[content_hotel['酒店名称'] == 'H27']
words_H27= scenic_spot_participle(H27)
words_H27_spec = words_name(words_H27)
data = words_H27_spec
# Out:
#  72%|████████████████████████████████████████████████████▎                    | 11061/15448 [00:00<00:00, 22771.61it/s]
# -1: 酒店 0.5092884905891821
# -2: 房间 0.3500048474419482
# -3: 不错 0.2661713510486672
# -4: 服务 0.21377541580286658
# -5: 小镇 0.20329622875370643
# -6: 环境 0.2012003913438744
# -7: 早餐 0.1991045539340424
# -8: 非常 0.16137948055706594
# -9: 欧洲 0.1320377568194176
# -10: 没有 0.12994191940958555
# -11: 适合 0.1257502445899215
# -12: 入住 0.11736689495059341
# -13: 设施 0.10688770790143329
# -14: 比较 0.09850435826210518
# -15: 升级 0.09850435826210518
# -16: 有点 0.09640852085227315
# -17: 很大 0.09012100862277708
# -18: 感觉 0.08802517121294505
# -19: 免费 0.08592933380311303
# -20: 疫情 0.07754598416378493
# -21: 前台 0.07754598416378493
# -22: 很多 0.07335430934412088
# -23: 泳池 0.06916263452445683
# -24: 孩子 0.06706679711462481
# -25: 味道 0.06497095970479277
# -26: 下次 0.06287512229496076
# -27: 地方 0.06287512229496076
# -28: 里面 0.06077928488512873
# -29: 卫生 0.06077928488512873
# -30: 干净 0.06077928488512873
# -31: 小孩 0.058683447475296704
# -32: 度假 0.058683447475296704
# -33: 可以 0.05658761006546468
# -34: 就是 0.05239593524580063
# -35: 舒服 0.05239593524580063
# -36: 拍照 0.05239593524580063
# -37: 期间 0.05239593524580063
# -38: 方便 0.0503000978359686
# -39: 游泳池 0.0503000978359686
# -40: 特别 0.048204260426136576
# -41: 小朋友 0.048204260426136576
# -42: 没什么 0.048204260426136576
# -43: 整体 0.04610842301630455
# -44: 开心 0.04610842301630455
# -45: 真的 0.04610842301630455
# -46: 晚上 0.04610842301630455
# -47: 但是 0.044012585606472525
# -48: 餐厅 0.041916748196640506
# -49: 喜欢 0.041916748196640506
# -50: 品种 0.03982091078680848

# %%
(
    WordCloud()
    .add(series_name="H27酒店特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="H27酒店特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="9ac67f3615074181bb9f40627621d884" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_9ac67f3615074181bb9f40627621d884 = echarts.init(
#                     document.getElementById('9ac67f3615074181bb9f40627621d884'), 'white', {renderer: 'canvas'});
#                 var option_9ac67f3615074181bb9f40627621d884 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "H27\u9152\u5e97\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u9152\u5e97",
#                     "value": "0.5092884905891821",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(127,128,82)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u623f\u95f4",
#                     "value": "0.3500048474419482",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(129,156,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.2661713510486672",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(156,92,48)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u670d\u52a1",
#                     "value": "0.21377541580286658",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,147,65)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c0f\u9547",
#                     "value": "0.20329622875370643",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(22,40,10)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73af\u5883",
#                     "value": "0.2012003913438744",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,8,79)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65e9\u9910",
#                     "value": "0.1991045539340424",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(101,24,24)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": "0.16137948055706594",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(49,82,6)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6b27\u6d32",
#                     "value": "0.1320377568194176",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(9,81,81)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ca1\u6709",
#                     "value": "0.12994191940958555",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(134,100,42)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9002\u5408",
#                     "value": "0.1257502445899215",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(81,37,106)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5165\u4f4f",
#                     "value": "0.11736689495059341",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(149,45,139)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bbe\u65bd",
#                     "value": "0.10688770790143329",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(36,83,22)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6bd4\u8f83",
#                     "value": "0.09850435826210518",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(147,91,145)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5347\u7ea7",
#                     "value": "0.09850435826210518",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(77,25,100)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6709\u70b9",
#                     "value": "0.09640852085227315",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(4,96,120)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f88\u5927",
#                     "value": "0.09012100862277708",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(91,137,11)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u611f\u89c9",
#                     "value": "0.08802517121294505",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(7,117,109)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u514d\u8d39",
#                     "value": "0.08592933380311303",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(141,25,71)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u75ab\u60c5",
#                     "value": "0.07754598416378493",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(87,110,137)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u524d\u53f0",
#                     "value": "0.07754598416378493",

# %% [markdown]
# ## 低评分的酒店特色

# %%
content_hotel_low = content_hotel_score.loc[content_hotel_score['总得分']<4.3].sort_values('总得分',ascending=False)
content_hotel_low.head()
# Out:
#     序号 酒店名称  总得分  服务得分  位置得分  设施得分  卫生得分  性价比得分
# 37  38  H38  4.2   4.2   4.3   4.0   4.3    4.0

# %%
H38 = content_hotel.loc[content_hotel['酒店名称'] == 'H38']
words_H38= scenic_spot_participle(H38)
words_H38_spec = words_name(words_H38)
data = words_H38_spec
# Out:
#  71%|████████████████████████████████████████████████████▉                     | 8336/11663 [00:00<00:00, 25717.77it/s]
# -1: 酒店 0.6302432117053949
# -2: 早餐 0.25363446324729305
# -3: 不错 0.24082464187116717
# -4: 设施 0.2357007133207168
# -5: 房间 0.2357007133207168
# -6: 沙滩 0.18446142781621314
# -7: 环境 0.1614037493391865
# -8: 没有 0.15371785651351094
# -9: 服务 0.14090803513738503
# -10: 比较 0.12809821376125913
# -11: 有点 0.11272642810990803
# -12: 入住 0.11272642810990803
# -13: 非常 0.10504053528423249
# -14: 泳池 0.1024785710090073
# -15: 适合 0.09223071390810657
# -16: 孩子 0.0871067853576562
# -17: 海滩 0.07942089253198066
# -18: 干净 0.0717349997063051
# -19: 位置 0.0717349997063051
# -20: 很多 0.06917303543107993
# -21: 前台 0.06917303543107993
# -22: 游泳池 0.06661107115585475
# -23: 真的 0.0589251783301792
# -24: 感觉 0.0589251783301792
# -25: 老旧 0.056363214054954015
# -26: 度假 0.056363214054954015
# -27: 五星级 0.05380124977972883
# -28: 陈旧 0.05380124977972883
# -29: 海景房 0.05123928550450365
# -30: 卫生 0.05123928550450365
# -31: 地方 0.0435533926788281
# -32: 丰富 0.0435533926788281
# -33: 味道 0.0435533926788281
# -34: 疫情 0.0435533926788281
# -35: 下次 0.04099142840360292
# -36: 时候 0.04099142840360292
# -37: 就是 0.04099142840360292
# -38: 沙子 0.04099142840360292
# -39: 满意 0.04099142840360292
# -40: 晚上 0.04099142840360292
# -41: 海边 0.04099142840360292
# -42: 五星 0.038429464128377736
# -43: 体验 0.038429464128377736
# -44: 开放 0.038429464128377736
# -45: 价格 0.038429464128377736
# -46: 但是 0.03586749985315255
# -47: 儿童 0.03586749985315255
# -48: 方便 0.03586749985315255
# -49: 室外 0.03586749985315255
# -50: 舒服 0.03586749985315255

# %%
(
    WordCloud()
    .add(series_name="H38酒店特色", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="H38酒店特色", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="25b92dc71d0143ddaaa8d6e413d48cf4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_25b92dc71d0143ddaaa8d6e413d48cf4 = echarts.init(
#                     document.getElementById('25b92dc71d0143ddaaa8d6e413d48cf4'), 'white', {renderer: 'canvas'});
#                 var option_25b92dc71d0143ddaaa8d6e413d48cf4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "H38\u9152\u5e97\u7279\u8272",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u9152\u5e97",
#                     "value": "0.6302432117053949",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(97,154,29)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65e9\u9910",
#                     "value": "0.25363446324729305",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(154,84,86)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": "0.24082464187116717",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(157,24,11)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bbe\u65bd",
#                     "value": "0.2357007133207168",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(82,155,35)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u623f\u95f4",
#                     "value": "0.2357007133207168",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(153,26,10)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6c99\u6ee9",
#                     "value": "0.18446142781621314",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(127,83,118)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73af\u5883",
#                     "value": "0.1614037493391865",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(31,45,9)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ca1\u6709",
#                     "value": "0.15371785651351094",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(24,95,142)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u670d\u52a1",
#                     "value": "0.14090803513738503",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,122,130)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6bd4\u8f83",
#                     "value": "0.12809821376125913",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,97,51)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6709\u70b9",
#                     "value": "0.11272642810990803",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(31,133,30)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5165\u4f4f",
#                     "value": "0.11272642810990803",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(140,30,130)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": "0.10504053528423249",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(58,63,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6cf3\u6c60",
#                     "value": "0.1024785710090073",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(117,5,90)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9002\u5408",
#                     "value": "0.09223071390810657",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(139,146,156)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b69\u5b50",
#                     "value": "0.0871067853576562",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(99,4,73)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6d77\u6ee9",
#                     "value": "0.07942089253198066",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(101,32,150)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e72\u51c0",
#                     "value": "0.0717349997063051",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(121,105,8)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f4d\u7f6e",
#                     "value": "0.0717349997063051",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(21,106,88)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f88\u591a",
#                     "value": "0.06917303543107993",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(89,33,89)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u524d\u53f0",
#                     "value": "0.06917303543107993",
