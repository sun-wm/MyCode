# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.layers import Dense,LSTM,Dropout
from keras.models import Sequential
from keras.optimizers import Adam

# %%
data = pd.read_excel('10.xls',sheet_name="监测数据报表",skiprows=2,parse_dates=['监测时间'],engine='openpyxl')  #读取excel表

# %%
data.drop(['备注','污水排口监控点排放量(吨)','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9'],axis=1,inplace=True)   #删除NaN列
data.drop(0,inplace=True)

# %%
data = data.set_index(['监测时间'])

# %%
data.drop(index=(data.loc[(data['PH值']=='停运')].index),inplace=True)

# %%
#显示函数
#解决中文显示问题
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False
def plot_data(test_result,predict_result):
    """
    test_result:真实值
    predict_result:预测值
    """
    plt.plot(test_result,color ='red',label = 'water element true value')
    plt.plot(predict_result,color ='blue',label = 'water element predicted value')
    plt.title("water element values")
    plt.xlabel("time")
    plt.ylabel("element values")
    plt.legend()
    plt.show()
data['化学需氧量(COD)(毫克/升)'] = data['化学需氧量(COD)(毫克/升)'].astype('float')
data['氨氮(毫克/升)'] = data['氨氮(毫克/升)'].astype('float')
data['PH值'] = data['PH值'].astype('float')

# %%
train_set = data[:'2020-06'].iloc[:,[0]].values
test_set = data['2020-07':].iloc[:,[0]].values

# %%
#正则化【0，1】加快拟合，提高预测准确率
sc = MinMaxScaler(feature_range=[0,1])
train_set_scaled = sc.fit_transform(train_set)

# %%
#创建序列测试集
#720（一周）个时间步为一个样本，一个输出
#构造X_text,预测
train_set = sc.transform(data[:'2020-06'].iloc[:,[0]].values)
test_set = sc.transform(data['2020-07':].iloc[:,[0]].values)

def create_data(dataset, look_back):
    X_train, Y_train = [], []
    for i in range(len(dataset)-look_back):
        X_train.append(dataset[i:(i+look_back)])
        Y_train.append(dataset[look_back+i:look_back+i+1])
    return np.array(X_train),np.array(Y_train)
look_back = 720
X_train,Y_train  = create_data(train_set,look_back)
X_test,Y_test = create_data(test_set,look_back)

# %%
#初始模型序列，加载两层LSTM层，128神经元，返回当前层输出
model = Sequential()
model.add(LSTM(128,return_sequences=True,input_shape=(X_train.shape[1],1)))
model.add(Dropout(0.2))#丢掉20%神经元

model.add(LSTM(128,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(128))
model.add(Dropout(0.2))

model.add(Dense(units=1))

# %%
model.compile(optimizer = 'adam',loss ='mse', metrics=['mse', 'mae'])#mse:均方误差 mae:平均绝对误差

model.fit(X_train,Y_train,epochs=10,verbose=1,validation_data=(X_test,Y_test))
# Out:
# Epoch 1/10
# 102/102 [==============================] - 138s 1s/step - loss: 0.0311 - mse: 0.0311 - mae: 0.1122 - val_loss: 7.9558e-04 - val_mse: 7.9558e-04 - val_mae: 0.0237
# Epoch 2/10
# 102/102 [==============================] - 131s 1s/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0402 - val_loss: 9.0423e-04 - val_mse: 9.0423e-04 - val_mae: 0.0246
# Epoch 3/10
# 102/102 [==============================] - 132s 1s/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0388 - val_loss: 7.4519e-04 - val_mse: 7.4519e-04 - val_mae: 0.0234
# Epoch 4/10
# 102/102 [==============================] - 132s 1s/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0392 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0259
# Epoch 5/10
# 102/102 [==============================] - 132s 1s/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0384 - val_loss: 6.5525e-04 - val_mse: 6.5525e-04 - val_mae: 0.0216
# Epoch 6/10
# 102/102 [==============================] - 132s 1s/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0375 - val_loss: 8.8996e-04 - val_mse: 8.8996e-04 - val_mae: 0.0232
# Epoch 7/10
# 102/102 [==============================] - 132s 1s/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0363 - val_loss: 9.2719e-04 - val_mse: 9.2719e-04 - val_mae: 0.0234
# Epoch 8/10
# 102/102 [==============================] - 132s 1s/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0331 - val_loss: 6.1215e-04 - val_mse: 6.1215e-04 - val_mae: 0.0188
# Epoch 9/10
# 102/102 [==============================] - 132s 1s/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0352 - val_loss: 3.4078e-04 - val_mse: 3.4078e-04 - val_mae: 0.0149
# Epoch 10/10
# 102/102 [==============================] - 132s 1s/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0331 - val_loss: 3.4412e-04 - val_mse: 3.4412e-04 - val_mae: 0.0147

# %%
predict = model.predict(X_test)

# %%
predict_result = sc.inverse_transform(predict)
predict_result
# Out:
# array([[7.7376685],
#        [7.7576494],
#        [7.740345 ],
#        [7.6936364],
#        [7.622796 ],
#        [7.5345955],
#        [7.4578886],
#        [7.4099455],
#        [7.389329 ],
#        [7.3838105],
#        [7.387866 ],
#        [7.396529 ],
#        [7.4030104],
#        [7.4043384],
#        [7.4033165],
#        [7.412211 ],
#        [7.433777 ],
#        [7.4613957],
#        [7.496162 ],
#        [7.531432 ],
#        [7.5545435],
#        [7.5643005],
#        [7.5672164],
#        [7.564825 ],
#        [7.5643945],
#        [7.564577 ],
#        [7.5648103],
#        [7.5606785],
#        [7.553043 ],
#        [7.538729 ],
#        [7.5172796],
#        [7.4956055],
#        [7.473959 ],
#        [7.45141  ],
#        [7.4298935],
#        [7.412079 ],
#        [7.4010177],
#        [7.393904 ],
#        [7.385005 ],
#        [7.374618 ],
#        [7.3749967],
#        [7.391809 ],
#        [7.4181952],
#        [7.4461594],
#        [7.465091 ],
#        [7.4693613],
#        [7.472687 ],
#        [7.482958 ],
#        [7.5056243],
#        [7.540241 ],
#        [7.5833845],
#        [7.6229997],
#        [7.652467 ],
#        [7.6667404],
#        [7.6674085],
#        [7.662483 ],
#        [7.658178 ],
#        [7.6581297],
#        [7.659757 ],
#        [7.658702 ],
#        [7.6524396],
#        [7.638979 ],
#        [7.615003 ],
#        [7.5813336],
#        [7.5436482],
#        [7.507654 ],
#        [7.4783163],
#        [7.4587793],
#        [7.4495835],
#        [7.449052 ],
#        [7.4543076],
#        [7.4776697],
#        [7.514945 ],
#        [7.552864 ],
#        [7.5881457],
#        [7.6214643],
#        [7.6350865],
#        [7.6244545],
#        [7.5981894],
#        [7.568166 ],
#        [7.5454803],
#        [7.529732 ],
#        [7.5171065],
#        [7.501959 ],
#        [7.4815545],
#        [7.455928 ],
#        [7.427846 ],
#        [7.401937 ],
#        [7.3825974],
#        [7.3741956],
#        [7.3813496],
#        [7.4108944],
#        [7.4507957],
#        [7.4968204],
#        [7.5454435],
#        [7.591758 ],
#        [7.632283 ],
#        [7.6620107],
#        [7.6753206],
#        [7.6715717],
#        [7.649784 ],
#        [7.6134443],
#        [7.57431  ],
#        [7.544322 ],
#        [7.5227995],
#        [7.5112624],
#        [7.507501 ],
#        [7.5063596],
#        [7.503404 ],
#        [7.496951 ],
#        [7.48645  ],
#        [7.4700203],
#        [7.4519877],
#        [7.437379 ],
#        [7.4461703],
#        [7.480143 ],
#        [7.523339 ],
#        [7.565125 ],
#        [7.612124 ],
#        [7.661278 ],
#        [7.7076855],
#        [7.743536 ],
#        [7.7647514],
#        [7.772933 ],
#        [7.766643 ],
#        [7.7485795],
#        [7.7235823],
#        [7.6872077],
#        [7.64401  ],
#        [7.604324 ],
#        [7.5732865],
#        [7.551884 ],
#        [7.538782 ],
#        [7.527708 ],
#        [7.5128555],
#        [7.495273 ],
#        [7.550972 ],
#        [7.5770793],
#        [7.6111174],
#        [7.65297  ],
#        [7.693803 ],
#        [7.7241235],
#        [7.7407117],
#        [7.741437 ],
#        [7.7258058],
#        [7.7006345],
#        [7.6727586],
#        [7.6404376],
#        [7.606203 ],
#        [7.571805 ],
#        [7.5403986],
#        [7.5131507],
#        [7.489815 ],
#        [7.4699893],
#        [7.4512615],
#        [7.434277 ],
#        [7.420911 ],
#        [7.41312  ],
#        [7.4109287],
#        [7.42097  ],
#        [7.456525 ],
#        [7.5106087],
#        [7.5667343],
#        [7.616289 ],
#        [7.6562576],
#        [7.686052 ],
#        [7.704926 ],
#        [7.713889 ],
#        [7.710833 ],
#        [7.702638 ],
#        [7.694096 ],
#        [7.6837907],
#        [7.666222 ],
#        [7.637457 ],
#        [7.5989704],
#        [7.5548267],
#        [7.508877 ],
#        [7.4657946],
#        [7.4313793],
#        [7.408987 ],
#        [7.3980436],
#        [7.3964586],
#        [7.404459 ],
#        [7.4204073],
#        [7.441    ],
#        [7.4676113],
#        [7.510766 ],
#        [7.562042 ],
#        [7.6106157],
#        [7.6481724],
#        [7.6672454],
#        [7.664957 ],
#        [7.6518574],
#        [7.6340613],
#        [7.615262 ],
#        [7.5888085],
#        [7.553989 ],
#        [7.515326 ],
#        [7.479649 ],
#        [7.4522467],
#        [7.435574 ],
#        [7.4285026],
#        [7.4216294],
#        [7.4089274],
#        [7.391451 ],
#        [7.3741813],
#        [7.3605747],
#        [7.352386 ],
#        [7.349587 ],
#        [7.350843 ],
#        [7.37996  ],
#        [7.440676 ],
#        [7.5165462],
#        [7.5890946],
#        [7.64437  ],
#        [7.677336 ],
#        [7.6842427],
#        [7.669505 ],
#        [7.642834 ],
#        [7.6070523],
#        [7.5654283],
#        [7.5225573],
#        [7.482412 ],
#        [7.4456472],
#        [7.411172 ],
#        [7.379682 ],
#        [7.3550463],
#        [7.3393555],
#        [7.3321652],
#        [7.3333945],
#        [7.3412066],
#        [7.3560953],
#        [7.384507 ],
#        [7.435986 ],
#        [7.500603 ],
#        [7.5621967],
#        [7.6093707],
#        [7.6408114],
#        [7.6584687],
#        [7.6652894],
#        [7.670656 ],
#        [7.678507 ],
#        [7.683838 ],
#        [7.677093 ],
#        [7.6526456],
#        [7.6131988],
#        [7.5665946],
#        [7.518604 ],
#        [7.472936 ],
#        [7.4328218],
#        [7.40119  ],
#        [7.3817434],
#        [7.3772955],
#        [7.385401 ],
#        [7.399486 ],
#        [7.4139385],
#        [7.4284816],
#        [7.456332 ],
#        [7.5044456],
#        [7.552696 ],
#        [7.580774 ],
#        [7.585244 ],
#        [7.5716515],
#        [7.551072 ],
#        [7.534046 ],
#        [7.5255637],
#        [7.527022 ],
#        [7.53465  ],
#        [7.537237 ],
#        [7.5282044],
#        [7.5074506],
#        [7.4793386],
#        [7.4457965],
#        [7.409794 ],
#        [7.378807 ],
#        [7.364072 ],
#        [7.370019 ],
#        [7.3909073],
#        [7.4190946],
#        [7.462415 ],
#        [7.5257154],
#        [7.600303 ],
#        [7.667044 ]], dtype=float32)

# %%
test_set = sc.inverse_transform(test_set)
plot_data(np.array(test_set),np.array(predict_result))

# %%
model.save("my_model")
